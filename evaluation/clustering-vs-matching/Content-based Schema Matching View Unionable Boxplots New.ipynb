# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid") 

dataset_type = 'view-unionable'

main_dir = 'C:/Users/G_A.Papadakis/OneDrive - Public Power Corporation S.A/Schema Matching/Valentine/'
df = pd.read_csv(main_dir + 'results_only_data_with_re_pr.csv')
df
# Out:
#                          filename   dataset           dataset_type  \
# 0     assays_horizontal_50_ac4_ev    assays              unionable
# 1     assays_horizontal_50_ac2_av    assays              unionable
# 2      assays_horizontal_0_ac4_ev    assays              unionable
# 3      assays_horizontal_0_ac5_ev    assays              unionable
# 4    assays_horizontal_100_ac3_ev    assays              unionable
# ..                            ...       ...                    ...
# 449    prospect_vertical_1_ac3_av  prospect  semantically-joinable
# 450    prospect_both_50_50_ac5_av  prospect  semantically-joinable
# 451    prospect_vertical_1_ac5_av  prospect  semantically-joinable
# 452    prospect_both_50_30_ac1_av  prospect  semantically-joinable
# 453         Musicians_semjoinable  Wikidata  semantically-joinable
#
#         UNI: F1     UNI: Re     UNI: Pr  UNI: runtime  \
# 0     88.888889   86.956522   90.909091      9.836186
# 1     86.956522   86.956522   86.956522     10.873166
# 2     86.956522   86.956522   86.956522      4.351686
# 3     86.956522   86.956522   86.956522      4.072706
# 4     88.888889   86.956522   90.909091     11.568633
# ..          ...         ...         ...           ...
# 449  100.000000  100.000000  100.000000      3.456857
# 450   72.727273   72.727273   72.727273     33.656137
# 451  100.000000  100.000000  100.000000      3.856011
# 452   90.909091   83.333333  100.000000      9.134220
# 453   82.352941   87.500000   77.777778     10.684985
#
#                                            UNI: params       K: F1  \
# 0    {'language_model': 'smpnet', 'similarity': 0.1...   93.023256
# 1    {'language_model': 'smpnet', 'similarity': 0.1...   90.476190
# 2    {'language_model': 'sminilm', 'similarity': 0....   90.476190
# 3    {'language_model': 'sminilm', 'similarity': 0....   90.476190
# 4    {'language_model': 'smpnet', 'similarity': 0.1...   93.023256
# ..                                                 ...         ...
# 449  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 450  {'language_model': 'st5', 'similarity': 0.1, '...   72.727273
# 451  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 452  {'language_model': 'smpnet', 'similarity': 0.8...   90.909091
# 453  {'language_model': 'smpnet', 'similarity': 0.1...   87.500000
#
#           K: Re  ...  TopKJoin-K: SUM & AVG   EJoin-K: SUM & AVG  \
# 0     86.956522  ...      116.8459490186785     133.435862317723
# 1     82.608696  ...    0.25736993175920375  0.29391159100820047
# 2     82.608696  ...
# 3     82.608696  ...
# 4     86.956522  ...
# ..          ...  ...                    ...                  ...
# 449  100.000000  ...
# 450   72.727273  ...
# 451  100.000000  ...
# 452   83.333333  ...
# 453   87.500000  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG       CU: SUM & AVG  \
# 0          86.61590486054772       114.1277885531925  452.82261381666086
# 1        0.19078393141089806      0.2513827941700275  0.9974066383626892
# 2
# 3
# 4
# ..                       ...                     ...                 ...
# 449
# 450
# 451
# 452
# 453
#
#           CO: SUM & AVG       DB: SUM & AVG      JDM: SUM & AVG  \
# 0     453.6607462462751  451.30789190933046  450.27955385373497
# 1    0.9992527450358483  0.9940702464963226  0.9918051846998568
# 2
# 3
# 4
# ..                  ...                 ...                 ...
# 449
# 450
# 451
# 452
# 453
#
#           SF: SUM & AVG  UNICORN: SUM & AVG
# 0     452.5413266706279   368.1752109754249
# 1    0.9967870631511627  0.8109586144833147
# 2
# 3
# 4
# ..                  ...                 ...
# 449
# 450
# 451
# 452
# 453
#
# [454 rows x 109 columns]

# %%
df[['dataset', 'dataset_type']].value_counts()
# Out:
# dataset   dataset_type
# assays    joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# miller2   joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# prospect  joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# assays    unionable                30
# miller2   unionable                30
# prospect  unionable                30
# Wikidata  joinable                  1
#           semantically-joinable     1
#           unionable                 1
#           view-unionable            1
# dtype: int64

# %%
datasets = df[df['dataset_type'] == dataset_type]
datasets
# Out:
#                       filename   dataset    dataset_type     UNI: F1  \
# 212    assays_both_0_70_ac2_av    assays  view-unionable   68.965517
# 213    assays_both_0_30_ac4_av    assays  view-unionable   60.000000
# 214    assays_both_0_50_ac5_ev    assays  view-unionable   80.000000
# 215     assays_both_0_1_ac3_av    assays  view-unionable   66.666667
# 216    assays_both_0_50_ac5_av    assays  view-unionable   76.923077
# ..                         ...       ...             ...         ...
# 328  prospect_both_0_70_ac4_av  prospect  view-unionable   78.571429
# 329  prospect_both_0_50_ac5_av  prospect  view-unionable   78.260870
# 330  prospect_both_0_70_ac5_av  prospect  view-unionable   82.758621
# 331  prospect_both_0_50_ac4_ev  prospect  view-unionable  100.000000
# 332        Musicians_viewunion  Wikidata  view-unionable   85.714286
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# 212   62.500000   76.923077    111.272432
# 213   50.000000   75.000000     17.428452
# 214   72.727273   88.888889      8.036194
# 215  100.000000   50.000000     23.363608
# 216   90.909091   66.666667      5.920936
# ..          ...         ...           ...
# 328   73.333333   84.615385     40.544012
# 329   81.818182   75.000000     34.013701
# 330   80.000000   85.714286     38.882953
# 331  100.000000  100.000000     10.100175
# 332  100.000000   75.000000      4.868275
#
#                                            UNI: params       K: F1  \
# 212  {'language_model': 'st5', 'similarity': 0.1, '...   75.862069
# 213  {'language_model': 'smpnet', 'similarity': 0.8...   80.000000
# 214  {'language_model': 'sdistilroberta', 'similari...   90.000000
# 215  {'language_model': 'smpnet', 'similarity': 0.8...   66.666667
# 216  {'language_model': 'sdistilroberta', 'similari...   80.000000
# ..                                                 ...         ...
# 328  {'language_model': 'st5', 'similarity': 0.1, '...   82.758621
# 329  {'language_model': 'st5', 'similarity': 0.7500...   76.190476
# 330  {'language_model': 'st5', 'similarity': 0.1, '...   85.714286
# 331  {'language_model': 'smpnet', 'similarity': 0.1...  100.000000
# 332  {'language_model': 'sminilm', 'similarity': 0....   85.714286
#
#           K: Re  ...  TopKJoin-K: SUM & AVG  EJoin-K: SUM & AVG  \
# 212   68.750000  ...
# 213   66.666667  ...
# 214   81.818182  ...
# 215  100.000000  ...
# 216   72.727273  ...
# ..          ...  ...                    ...                 ...
# 328   80.000000  ...
# 329   72.727273  ...
# 330   80.000000  ...
# 331  100.000000  ...
# 332  100.000000  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG  CU: SUM & AVG  \
# 212
# 213
# 214
# 215
# 216
# ..                       ...                     ...            ...
# 328
# 329
# 330
# 331
# 332
#
#      CO: SUM & AVG DB: SUM & AVG  JDM: SUM & AVG  SF: SUM & AVG  \
# 212
# 213
# 214
# 215
# 216
# ..             ...           ...             ...            ...
# 328
# 329
# 330
# 331
# 332
#
#      UNICORN: SUM & AVG
# 212
# 213
# 214
# 215
# 216
# ..                  ...
# 328
# 329
# 330
# 331
# 332
#
# [121 rows x 109 columns]

# %%
f1 = datasets.filter(regex='F1').copy()
f1
# Out:
#         UNI: F1       K: F1  TopKJoin-UNI: F1  EJoin-UNI: F1  TopKJoin-K: F1  \
# 212   68.965517   75.862069         60.000000      51.612903       64.000000
# 213   60.000000   80.000000         40.000000      44.444444       44.444444
# 214   80.000000   90.000000         70.000000      70.000000       73.684211
# 215   66.666667   66.666667          0.000000       0.000000        0.000000
# 216   76.923077   80.000000         58.823529      47.058824       50.000000
# ..          ...         ...               ...            ...             ...
# 328   78.571429   82.758621         53.846154      51.851852       53.846154
# 329   78.260870   76.190476         47.058824      57.142857       50.000000
# 330   82.758621   85.714286         66.666667      62.500000       66.666667
# 331  100.000000  100.000000         95.652174      95.238095      100.000000
# 332   85.714286   85.714286        100.000000      83.333333      100.000000
#
#      EJoin-K: F1  syntactic-UNI: F1  syntactic-K: F1    CO: F1    CU: F1  \
# 212    45.454545          54.545455        38.095238  0.000000  0.242424
# 213    36.363636          22.222222        25.000000  0.000000  0.200000
# 214    73.684211          95.238095        73.684211  0.125000  0.240000
# 215     0.000000           0.000000         0.000000  0.000000  0.222222
# 216    50.000000          66.666667        58.823529  0.000000  0.400000
# ..           ...                ...              ...       ...       ...
# 328    36.363636          76.923077        64.000000  0.315789  0.000000
# 329    50.000000          73.684211        73.684211  0.000000  0.320000
# 330    60.869565          76.923077        64.000000  0.300000  0.000000
# 331   100.000000          95.238095        95.238095  0.125000  0.333333
# 332    85.714286          92.307692        92.307692  0.363636  0.444444
#
#        DB: F1    SF: F1   JDM: F1  UNICORN: F1      max F1
# 212  0.416667  0.516129  0.640000     9.090869   75.862069
# 213  0.250000  0.307692  0.545455     0.000000   80.000000
# 214  0.736842  0.200000  0.777778    26.666624   95.238095
# 215  0.000000  0.000000  0.500000     0.000000   66.666667
# 216  0.235294  0.416667  0.705882    16.666649   80.000000
# ..        ...       ...       ...          ...         ...
# 328  0.363636  0.758621  0.666667    22.222192   82.758621
# 329  0.526316  0.608696  0.800000    15.384587   78.260870
# 330  0.636364  0.758621  0.750000    22.222192   85.714286
# 331  0.900000  0.608696  0.909091    15.384587  100.000000
# 332  0.727273  0.500000  0.923077    72.727210  100.000000
#
# [121 rows x 15 columns]

# %%
f1 = datasets.filter(regex='F1').copy()
f1.drop(columns=['max F1'], inplace=True)
f1.rename(columns={'UNI: F1':'SemU', 'K: F1':'SemK', 'TopKJoin-UNI: F1':'SynU', 'TopKJoin-K: F1':'SynK',
                   'EJoin-UNI: F1':'SimU', 'EJoin-K: F1':'SimK',                
                   'syntactic-UNI: F1':'BlU', 'syntactic-K: F1':'BlK',
                   'CU: F1':'CU', 'CO: F1':'CO','DB: F1':'DB', 'JDM: F1':'JDM', 
                   'SF: F1':'SF', 'EmbDI: F1': 'EmbDI', 'UNICORN: F1':'UNC'}, inplace=True)
cols = list(f1.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
f1 = f1[cols]
f1
# Out:
#            SemU        SemK        SynU        SynK       SimU        SimK  \
# 212   68.965517   75.862069   60.000000   64.000000  51.612903   45.454545
# 213   60.000000   80.000000   40.000000   44.444444  44.444444   36.363636
# 214   80.000000   90.000000   70.000000   73.684211  70.000000   73.684211
# 215   66.666667   66.666667    0.000000    0.000000   0.000000    0.000000
# 216   76.923077   80.000000   58.823529   50.000000  47.058824   50.000000
# ..          ...         ...         ...         ...        ...         ...
# 328   78.571429   82.758621   53.846154   53.846154  51.851852   36.363636
# 329   78.260870   76.190476   47.058824   50.000000  57.142857   50.000000
# 330   82.758621   85.714286   66.666667   66.666667  62.500000   60.869565
# 331  100.000000  100.000000   95.652174  100.000000  95.238095  100.000000
# 332   85.714286   85.714286  100.000000  100.000000  83.333333   85.714286
#
#            BlU        BlK         CO         CU         DB         SF  \
# 212  54.545455  38.095238   0.000000  24.242424  41.666667  51.612903
# 213  22.222222  25.000000   0.000000  20.000000  25.000000  30.769231
# 214  95.238095  73.684211  12.500000  24.000000  73.684211  20.000000
# 215   0.000000   0.000000   0.000000  22.222222   0.000000   0.000000
# 216  66.666667  58.823529   0.000000  40.000000  23.529412  41.666667
# ..         ...        ...        ...        ...        ...        ...
# 328  76.923077  64.000000  31.578947   0.000000  36.363636  75.862069
# 329  73.684211  73.684211   0.000000  32.000000  52.631579  60.869565
# 330  76.923077  64.000000  30.000000   0.000000  63.636364  75.862069
# 331  95.238095  95.238095  12.500000  33.333333  90.000000  60.869565
# 332  92.307692  92.307692  36.363636  44.444444  72.727273  50.000000
#
#            JDM        UNC
# 212  64.000000   9.090869
# 213  54.545455   0.000000
# 214  77.777778  26.666624
# 215  50.000000   0.000000
# 216  70.588235  16.666649
# ..         ...        ...
# 328  66.666667  22.222192
# 329  80.000000  15.384587
# 330  75.000000  22.222192
# 331  90.909091  15.384587
# 332  92.307692  72.727210
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(f1)
ax.set_title("F-Measure") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_f1')

# %%
f1.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    71.199266   72.813611   49.645968   48.987444   47.085048   45.545691
# std     21.450087   21.416061   32.614147   31.771421   31.385463   30.842959
# min     16.666667   16.666667    0.000000    0.000000    0.000000    0.000000
# 25%     60.000000   62.068966   22.222222   28.571429   18.181818   25.641026
# 50%     77.419355   77.777778   57.142857   52.631579   51.851852   51.612903
# 75%     85.714286   88.888889   78.571429   76.190476   75.675676   72.727273
# max    100.000000  100.000000  100.000000  100.000000   95.238095  100.000000
#
#               BlU         BlK          CO          CU          DB          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    53.484639   49.870066    5.553440   20.378211   33.898129   29.045406
# std     34.118038   31.400766    9.013031   17.368603   27.368302   29.654643
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     25.000000   25.000000    0.000000    0.000000    7.692308    0.000000
# 50%     61.538462   61.538462    0.000000   22.222222   30.508475   14.285714
# 75%     83.333333   74.418605   10.000000   36.363636   55.555556   54.545455
# max    100.000000   95.238095   36.363636   55.172414   90.000000   83.333333
#
#               JDM         UNC
# count  121.000000  121.000000
# mean    57.435706   12.442193
# std     24.995814   14.091340
# min      0.000000    0.000000
# 25%     50.000000    0.000000
# 50%     61.538462    9.523768
# 75%     76.923077   21.052596
# max     95.238095   72.727210

# %%
re = datasets.filter(regex='Re').copy()
re.rename(columns={'UNI: Re':'SemU', 'K: Re':'SemK', 'TopKJoin-UNI: Re':'SynU', 'TopKJoin-K: Re':'SynK',
                   'EJoin-UNI: Re':'SimU', 'EJoin-K: Re':'SimK',                
                   'syntactic-UNI: Re':'BlU', 'syntactic-K: Re':'BlK',
                   'CU: Re':'CU', 'CO: Re':'CO','DB: Re':'DB', 'JDM: Re':'JDM', 
                   'SF: Re':'SF', 'EmbDI: Re': 'EmbDI', 'UNICORN: Re':'UNC'}, inplace=True)
cols = list(re.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
re = re[cols]
re
# Out:
#            SemU        SemK        SynU        SynK       SimU        SimK  \
# 212   62.500000   68.750000   56.250000   50.000000  50.000000   31.250000
# 213   50.000000   66.666667   50.000000   33.333333  66.666667   33.333333
# 214   72.727273   81.818182   63.636364   63.636364  63.636364   63.636364
# 215  100.000000  100.000000    0.000000    0.000000   0.000000    0.000000
# 216   90.909091   72.727273   45.454545   36.363636  36.363636   36.363636
# ..          ...         ...         ...         ...        ...         ...
# 328   73.333333   80.000000   46.666667   46.666667  46.666667   26.666667
# 329   81.818182   72.727273   36.363636   45.454545  54.545455   45.454545
# 330   80.000000   80.000000   53.333333   53.333333  66.666667   46.666667
# 331  100.000000  100.000000  100.000000  100.000000  90.909091  100.000000
# 332  100.000000  100.000000  100.000000  100.000000  83.333333  100.000000
#
#             BlU         BlK         CO          CU         DB         SF  \
# 212   37.500000   25.000000   0.000000   25.000000  31.250000  50.000000
# 213   16.666667   16.666667   0.000000   33.333333  16.666667  33.333333
# 214   90.909091   63.636364   9.090909   27.272727  63.636364  18.181818
# 215    0.000000    0.000000   0.000000  100.000000   0.000000   0.000000
# 216   54.545455   45.454545   0.000000   45.454545  18.181818  45.454545
# ..          ...         ...        ...         ...        ...        ...
# 328   66.666667   53.333333  20.000000    0.000000  26.666667  73.333333
# 329   63.636364   63.636364   0.000000   36.363636  45.454545  63.636364
# 330   66.666667   53.333333  20.000000    0.000000  46.666667  73.333333
# 331   90.909091   90.909091   9.090909   36.363636  81.818182  63.636364
# 332  100.000000  100.000000  33.333333   66.666667  66.666667  33.333333
#
#             JDM        UNC
# 212   50.000000   6.250000
# 213   50.000000   0.000000
# 214   63.636364  18.181817
# 215  100.000000   0.000000
# 216   54.545455   9.090908
# ..          ...        ...
# 328   53.333333  13.333332
# 329   72.727273   9.090908
# 330   60.000000  13.333332
# 331   90.909091   9.090908
# 332  100.000000  66.666656
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(re)
ax.set_title("Recall") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_re')

# %%
re.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    79.247540   78.721969   50.915084   46.750778   50.650335   43.653071
# std     18.343590   18.851054   33.708937   32.029277   32.682427   31.275769
# min     33.333333   40.000000    0.000000    0.000000    0.000000    0.000000
# 25%     66.666667   66.666667   28.000000   20.000000   16.666667   20.000000
# 50%     80.000000   81.250000   54.545455   50.000000   54.545455   45.454545
# 75%    100.000000  100.000000   81.250000   73.333333   76.000000   66.666667
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CO          CU          DB          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    51.160907   44.144118    3.998623   31.437283   31.880085   30.865738
# std     34.665059   30.745109    6.639949   30.495218   27.694605   31.788158
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     16.666667   16.666667    0.000000    0.000000    6.666667    0.000000
# 50%     54.545455   50.000000    0.000000   28.571429   31.250000   16.666667
# 75%     81.818182   66.666667    6.666667   50.000000   50.000000   62.500000
# max    100.000000  100.000000   33.333333  100.000000  100.000000   90.909091
#
#               JDM         UNC
# count  121.000000  121.000000
# mean    69.411810    8.677766
# std     26.933405   10.760767
# min      0.000000    0.000000
# 25%     50.000000    0.000000
# 50%     68.571429    6.666666
# 75%    100.000000   13.333332
# max    100.000000   66.666656

# %%
pr = datasets.filter(regex='Pr').copy()
pr.rename(columns={'UNI: Pr':'SemU', 'K: Pr':'SemK', 'TopKJoin-UNI: Pr':'SynU', 'TopKJoin-K: Pr':'SynK',
                   'EJoin-UNI: Pr':'SimU', 'EJoin-K: Pr':'SimK',                
                   'syntactic-UNI: Pr':'BlU', 'syntactic-K: Pr':'BlK',
                   'CU: Pr':'CU', 'CO: Pr':'CO','DB: Pr':'DB', 'JDM: Pr':'JDM', 
                   'SF: Pr':'SF', 'EmbDI: Pr': 'EmbDI', 'UNICORN: Pr':'UNC'}, inplace=True)
cols = list(pr.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
pr = pr[cols]
pr
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 212   76.923077   84.615385   64.285714   88.888889   53.333333   83.333333
# 213   75.000000  100.000000   33.333333   66.666667   33.333333   40.000000
# 214   88.888889  100.000000   77.777778   87.500000   77.777778   87.500000
# 215   50.000000   50.000000    0.000000    0.000000    0.000000    0.000000
# 216   66.666667   88.888889   83.333333   80.000000   66.666667   80.000000
# ..          ...         ...         ...         ...         ...         ...
# 328   84.615385   85.714286   63.636364   63.636364   58.333333   57.142857
# 329   75.000000   80.000000   66.666667   55.555556   60.000000   55.555556
# 330   85.714286   92.307692   88.888889   88.888889   58.823529   87.500000
# 331  100.000000  100.000000   91.666667  100.000000  100.000000  100.000000
# 332   75.000000   75.000000  100.000000  100.000000   83.333333   75.000000
#
#             BlU         BlK    CO         CU          DB          SF  \
# 212  100.000000   80.000000   0.0  23.529412   62.500000   53.333333
# 213   33.333333   50.000000   0.0  14.285714   50.000000   28.571429
# 214  100.000000   87.500000  20.0  21.428571   87.500000   22.222222
# 215    0.000000    0.000000   0.0  12.500000    0.000000    0.000000
# 216   85.714286   83.333333   0.0  35.714286   33.333333   38.461538
# ..          ...         ...   ...        ...         ...         ...
# 328   90.909091   80.000000  75.0   0.000000   57.142857   78.571429
# 329   87.500000   87.500000   0.0  28.571429   62.500000   58.333333
# 330   90.909091   80.000000  60.0   0.000000  100.000000   78.571429
# 331  100.000000  100.000000  20.0  30.769231  100.000000   58.333333
# 332   85.714286   85.714286  40.0  33.333333   80.000000  100.000000
#
#             JDM        UNC
# 212   88.888889  16.666664
# 213   60.000000   0.000000
# 214  100.000000  49.999988
# 215   33.333333   0.000000
# 216  100.000000  99.999900
# ..          ...        ...
# 328   88.888889  66.666644
# 329   88.888889  49.999975
# 330  100.000000  66.666644
# 331   90.909091  49.999975
# 332   85.714286  79.999984
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(pr)
ax.set_title("Precision") 
ax.tick_params(axis='both', labelsize=12)
plt.xticks(rotation=45)
plt.ylim(-1, 101)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_pr')

# %%
pr.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    71.291730   75.492928   53.291824   56.947990   48.385089   53.461845
# std     25.275955   25.865751   35.492574   36.116752   33.912206   36.130162
# min      9.090909    9.090909    0.000000    0.000000    0.000000    0.000000
# 25%     53.333333   60.000000   12.500000   20.000000   10.000000   16.666667
# 50%     80.000000   85.714286   64.285714   66.666667   57.142857   60.000000
# 75%     90.476190  100.000000   83.333333   87.500000   72.727273   83.333333
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK         CO          CU          DB          SF  \
# count  121.000000  121.000000  121.00000  121.000000  121.000000  121.000000
# mean    60.672058   61.944645   10.05772   16.943981   42.968623   29.180505
# std     38.368902   36.585981   16.97604   15.020508   35.392080   29.589252
# min      0.000000    0.000000    0.00000    0.000000    0.000000    0.000000
# 25%     33.333333   50.000000    0.00000    0.000000    9.090909    0.000000
# 50%     73.684211   75.000000    0.00000   15.384615   35.714286   16.666667
# 75%    100.000000   90.909091   20.00000   29.032258   75.000000   52.941176
# max    100.000000  100.000000   75.00000   51.282051  100.000000  100.000000
#
#               JDM         UNC
# count  121.000000  121.000000
# mean    58.913385   27.854763
# std     30.188716   31.062465
# min      0.000000    0.000000
# 25%     33.333333    0.000000
# 50%     66.666667   16.666664
# 75%     85.714286   49.999975
# max    100.000000   99.999980

# %%
f1['max_value'] = f1.max(axis=1)
f1
# Out:
#            SemU        SemK        SynU        SynK       SimU        SimK  \
# 212   68.965517   75.862069   60.000000   64.000000  51.612903   45.454545
# 213   60.000000   80.000000   40.000000   44.444444  44.444444   36.363636
# 214   80.000000   90.000000   70.000000   73.684211  70.000000   73.684211
# 215   66.666667   66.666667    0.000000    0.000000   0.000000    0.000000
# 216   76.923077   80.000000   58.823529   50.000000  47.058824   50.000000
# ..          ...         ...         ...         ...        ...         ...
# 328   78.571429   82.758621   53.846154   53.846154  51.851852   36.363636
# 329   78.260870   76.190476   47.058824   50.000000  57.142857   50.000000
# 330   82.758621   85.714286   66.666667   66.666667  62.500000   60.869565
# 331  100.000000  100.000000   95.652174  100.000000  95.238095  100.000000
# 332   85.714286   85.714286  100.000000  100.000000  83.333333   85.714286
#
#            BlU        BlK         CO         CU         DB         SF  \
# 212  54.545455  38.095238   0.000000  24.242424  41.666667  51.612903
# 213  22.222222  25.000000   0.000000  20.000000  25.000000  30.769231
# 214  95.238095  73.684211  12.500000  24.000000  73.684211  20.000000
# 215   0.000000   0.000000   0.000000  22.222222   0.000000   0.000000
# 216  66.666667  58.823529   0.000000  40.000000  23.529412  41.666667
# ..         ...        ...        ...        ...        ...        ...
# 328  76.923077  64.000000  31.578947   0.000000  36.363636  75.862069
# 329  73.684211  73.684211   0.000000  32.000000  52.631579  60.869565
# 330  76.923077  64.000000  30.000000   0.000000  63.636364  75.862069
# 331  95.238095  95.238095  12.500000  33.333333  90.000000  60.869565
# 332  92.307692  92.307692  36.363636  44.444444  72.727273  50.000000
#
#            JDM        UNC   max_value
# 212  64.000000   9.090869   75.862069
# 213  54.545455   0.000000   80.000000
# 214  77.777778  26.666624   95.238095
# 215  50.000000   0.000000   66.666667
# 216  70.588235  16.666649   80.000000
# ..         ...        ...         ...
# 328  66.666667  22.222192   82.758621
# 329  80.000000  15.384587   80.000000
# 330  75.000000  22.222192   85.714286
# 331  90.909091  15.384587  100.000000
# 332  92.307692  72.727210  100.000000
#
# [121 rows x 15 columns]

# %%
f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
#f1['EMBDI_DFT'] = 1- f1['EmbDI']/f1['max_value']
f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
f1
# Out:
#            SemU        SemK        SynU        SynK       SimU        SimK  \
# 212   68.965517   75.862069   60.000000   64.000000  51.612903   45.454545
# 213   60.000000   80.000000   40.000000   44.444444  44.444444   36.363636
# 214   80.000000   90.000000   70.000000   73.684211  70.000000   73.684211
# 215   66.666667   66.666667    0.000000    0.000000   0.000000    0.000000
# 216   76.923077   80.000000   58.823529   50.000000  47.058824   50.000000
# ..          ...         ...         ...         ...        ...         ...
# 328   78.571429   82.758621   53.846154   53.846154  51.851852   36.363636
# 329   78.260870   76.190476   47.058824   50.000000  57.142857   50.000000
# 330   82.758621   85.714286   66.666667   66.666667  62.500000   60.869565
# 331  100.000000  100.000000   95.652174  100.000000  95.238095  100.000000
# 332   85.714286   85.714286  100.000000  100.000000  83.333333   85.714286
#
#            BlU        BlK         CO         CU  ...  SimU_DFT  SimK_DFT  \
# 212  54.545455  38.095238   0.000000  24.242424  ...  0.319648  0.400826
# 213  22.222222  25.000000   0.000000  20.000000  ...  0.444444  0.545455
# 214  95.238095  73.684211  12.500000  24.000000  ...  0.265000  0.226316
# 215   0.000000   0.000000   0.000000  22.222222  ...  1.000000  1.000000
# 216  66.666667  58.823529   0.000000  40.000000  ...  0.411765  0.375000
# ..         ...        ...        ...        ...  ...       ...       ...
# 328  76.923077  64.000000  31.578947   0.000000  ...  0.373457  0.560606
# 329  73.684211  73.684211   0.000000  32.000000  ...  0.285714  0.375000
# 330  76.923077  64.000000  30.000000   0.000000  ...  0.270833  0.289855
# 331  95.238095  95.238095  12.500000  33.333333  ...  0.047619  0.000000
# 332  92.307692  92.307692  36.363636  44.444444  ...  0.166667  0.142857
#
#       BlU_DFT   BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT  \
# 212  0.280992  0.497835  0.680441  1.000000  0.450758  0.156364  0.319648
# 213  0.722222  0.687500  0.750000  1.000000  0.687500  0.318182  0.615385
# 214  0.000000  0.226316  0.748000  0.868750  0.226316  0.183333  0.790000
# 215  1.000000  1.000000  0.666667  1.000000  1.000000  0.250000  1.000000
# 216  0.166667  0.264706  0.500000  1.000000  0.705882  0.117647  0.479167
# ..        ...       ...       ...       ...       ...       ...       ...
# 328  0.070513  0.226667  1.000000  0.618421  0.560606  0.194444  0.083333
# 329  0.078947  0.078947  0.600000  1.000000  0.342105  0.000000  0.239130
# 330  0.102564  0.253333  1.000000  0.650000  0.257576  0.125000  0.114943
# 331  0.047619  0.047619  0.666667  0.875000  0.100000  0.090909  0.391304
# 332  0.076923  0.076923  0.555556  0.636364  0.272727  0.076923  0.500000
#
#       UNC_DFT
# 212  0.880166
# 213  1.000000
# 214  0.720000
# 215  1.000000
# 216  0.791667
# ..        ...
# 328  0.731482
# 329  0.807693
# 330  0.740741
# 331  0.846154
# 332  0.272728
#
# [121 rows x 29 columns]

# %%
dft = f1.filter(regex='DFT').copy()
dft
# Out:
#      SemU_DFT  SemK_DFT  SynU_DFT  SynK_DFT  SimU_DFT  SimK_DFT   BlU_DFT  \
# 212  0.090909  0.000000  0.209091  0.156364  0.319648  0.400826  0.280992
# 213  0.250000  0.000000  0.500000  0.444444  0.444444  0.545455  0.722222
# 214  0.160000  0.055000  0.265000  0.226316  0.265000  0.226316  0.000000
# 215  0.000000  0.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 216  0.038462  0.000000  0.264706  0.375000  0.411765  0.375000  0.166667
# ..        ...       ...       ...       ...       ...       ...       ...
# 328  0.050595  0.000000  0.349359  0.349359  0.373457  0.560606  0.070513
# 329  0.021739  0.047619  0.411765  0.375000  0.285714  0.375000  0.078947
# 330  0.034483  0.000000  0.222222  0.222222  0.270833  0.289855  0.102564
# 331  0.000000  0.000000  0.043478  0.000000  0.047619  0.000000  0.047619
# 332  0.142857  0.142857  0.000000  0.000000  0.166667  0.142857  0.076923
#
#       BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT   UNC_DFT
# 212  0.497835  0.680441  1.000000  0.450758  0.156364  0.319648  0.880166
# 213  0.687500  0.750000  1.000000  0.687500  0.318182  0.615385  1.000000
# 214  0.226316  0.748000  0.868750  0.226316  0.183333  0.790000  0.720000
# 215  1.000000  0.666667  1.000000  1.000000  0.250000  1.000000  1.000000
# 216  0.264706  0.500000  1.000000  0.705882  0.117647  0.479167  0.791667
# ..        ...       ...       ...       ...       ...       ...       ...
# 328  0.226667  1.000000  0.618421  0.560606  0.194444  0.083333  0.731482
# 329  0.078947  0.600000  1.000000  0.342105  0.000000  0.239130  0.807693
# 330  0.253333  1.000000  0.650000  0.257576  0.125000  0.114943  0.740741
# 331  0.047619  0.666667  0.875000  0.100000  0.090909  0.391304  0.846154
# 332  0.076923  0.555556  0.636364  0.272727  0.076923  0.500000  0.272728
#
# [121 rows x 14 columns]

# %%
dft.describe()
# Out:
#          SemU_DFT    SemK_DFT    SynU_DFT    SynK_DFT    SimU_DFT    SimK_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.098074    0.075175    0.397729    0.406998    0.430028    0.449772
# std      0.142542    0.138687    0.362072    0.347865    0.347515    0.341189
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.116071    0.133333    0.160000    0.185345
# 50%      0.050595    0.000000    0.250000    0.272727    0.277778    0.332308
# 75%      0.142857    0.114754    0.666667    0.558824    0.727273    0.633333
# max      0.625000    0.625000    1.000000    1.000000    1.000000    1.000000
#
#           BlU_DFT     BlK_DFT      CU_DFT      CO_DFT      DB_DFT     JDM_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.349860    0.388645    0.728249    0.937324    0.597786    0.263866
# std      0.378616    0.359405    0.253893    0.101768    0.302152    0.254125
# min      0.000000    0.000000    0.000000    0.618421    0.073684    0.000000
# 25%      0.069069    0.102564    0.587848    0.887218    0.333333    0.090909
# 50%      0.166667    0.231638    0.693878    1.000000    0.625000    0.196429
# 75%      0.592593    0.588235    1.000000    1.000000    0.867521    0.294118
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            SF_DFT     UNC_DFT
# count  121.000000  121.000000
# mean     0.634100    0.852178
# std      0.373856    0.153923
# min      0.000000    0.272728
# 25%      0.230769    0.760395
# 50%      0.812500    0.862319
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
dft.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
rt = datasets.filter(regex='runtime').copy()
rt.rename(columns={'UNI: runtime':'SemU', 'K: runtime':'SemK', 'TopKJoin-UNI: runtime':'SynU', 'TopKJoin-K: runtime':'SynK',
                   'EJoin-UNI: runtime':'SimU', 'EJoin-K: runtime':'SimK',                
                   'syntactic-UNI: runtime':'BlU', 'syntactic-K: runtime':'BlK',
                   'CU: runtime':'CU', 'CO: runtime':'CO','DB: runtime':'DB', 'JDM: runtime':'JDM', 
                   'SF: runtime':'SF', 'EmbDI: runtime': 'EmbDI', 'UNICORN: runtime':'UNC'}, inplace=True)
cols = list(rt.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
rt = rt[cols]
rt
# Out:
#            SemU        SemK      SynU      SynK      SimU      SimK  \
# 212  111.272432  111.377450  0.064182  0.132652  0.062634  0.140865
# 213   17.428452   17.475908  0.038245  0.083649  0.038080  0.089667
# 214    8.036194    8.090486  0.028950  0.086320  0.027610  0.093607
# 215   23.363608   23.401262  0.025596  0.059497  0.025373  0.064161
# 216    5.920936    5.150155  0.045781  0.101789  0.044794  0.110854
# ..          ...         ...       ...       ...       ...       ...
# 328   40.544012    4.746232  0.149910  0.214970  0.148985  0.236047
# 329   34.013701    7.883695  0.120528  0.184054  0.118762  0.192238
# 330   38.882953   36.388323  0.144345  0.210638  0.137442  0.220191
# 331   10.100175   10.158001  0.098879  0.159412  0.096447  0.170082
# 332    4.868275    4.910575  0.123287  0.168731  0.122209  0.184360
#
#            BlU        BlK          CO         CU         DB        SF  \
# 212   9.534769   9.534664   81.723342  18.885077  12.172903  1.466290
# 213   0.159712   0.159655   42.169294  18.706989   8.035800  0.783010
# 214   0.099332   0.099221   44.358986  18.798560   8.972124  1.085423
# 215   0.067154   0.067273   29.749987  18.211564   8.662974  0.736692
# 216   0.174985   0.175015   58.737205  19.043503  10.439194  1.114565
# ..         ...        ...         ...        ...        ...       ...
# 328   0.154904   0.189145  328.117668  18.555302  10.970877  1.307745
# 329  29.992196  29.992085  266.205621  18.308059  10.842740  0.947065
# 330  31.124708   1.142252  312.323232  18.083338  11.553877  1.214074
# 331   0.822418   0.822345  268.753760  18.197922  12.007195  1.037147
# 332   3.523148   3.523114   79.927989  18.722262   8.201621  0.599933
#
#              JDM       UNC
# 212  1429.726215  2.973886
# 213  1268.405351  1.536582
# 214  1266.237188  1.753892
# 215  1256.271915  0.949180
# 216  1355.984074  2.087659
# ..           ...       ...
# 328  1786.856142  4.071691
# 329  1427.423996  3.185242
# 330  1495.489847  3.933106
# 331  1446.891025  2.920340
# 332   590.052900  0.804980
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(rt)
ax.set_title("Run-time") 
ax.tick_params(axis='both', labelsize=12)
plt.yscale('log')
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_rt')

# %%
rt.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    19.636698   21.736640    0.085326    0.152075    0.083972    0.181926
# std     20.102222   21.258545    0.045420    0.068153    0.045970    0.099754
# min      3.581682    3.631135    0.025266    0.058895    0.025290    0.063966
# 25%      5.739248    5.855618    0.048127    0.101740    0.046191    0.104463
# 50%      9.053834   11.218367    0.078278    0.141621    0.075583    0.147593
# 75%     30.281832   32.716656    0.117173    0.199456    0.114917    0.226720
# max    111.272432  111.377450    0.206135    0.345791    0.211272    0.502373
#
#               BlU         BlK           CO          CU          DB  \
# count  121.000000  121.000000   121.000000  121.000000  121.000000
# mean     5.756121    4.984082   392.682726   18.729393   16.049049
# std     13.852198   14.364700   438.313562    0.781903   10.480240
# min      0.038081    0.038044    28.836001   17.724942    7.871892
# 25%      0.151056    0.162427    71.266284   18.288139    8.951526
# 50%      0.296800    0.332691   200.329487   18.647040   10.842740
# 75%      2.145698    2.069950   503.686599   19.034677   20.160411
# max     70.189522   70.189457  1565.907166   24.956970   46.431127
#
#                SF          JDM         UNC
# count  121.000000   121.000000  121.000000
# mean     2.848769  1330.407088    4.568522
# std      3.355174  1380.222931    4.076712
# min      0.530150    40.382845    0.804980
# 25%      0.826953   564.554812    1.570893
# 50%      1.208982  1253.312196    2.973886
# 75%      4.632340  1427.423996    4.730446
# max     19.191643  7023.302423   16.274604
