# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid") 

dataset_type = 'semantically-joinable'

main_dir = 'C:/Users/G_A.Papadakis/OneDrive - Public Power Corporation S.A/Schema Matching/Valentine/'
df = pd.read_csv(main_dir + 'results_only_schema_with_re_pr.csv')
df
# Out:
#                         filename   dataset           dataset_type     UNI: F1  \
# 0     assays_horizontal_0_ac1_av    assays              unionable  100.000000
# 1    assays_horizontal_50_ac5_av    assays              unionable   41.025641
# 2    assays_horizontal_50_ac5_ev    assays              unionable   41.025641
# 3     assays_horizontal_0_ac2_ev    assays              unionable   74.418605
# 4    assays_horizontal_50_ac2_av    assays              unionable   68.571429
# ..                           ...       ...                    ...         ...
# 449   prospect_both_50_30_ac2_av  prospect  semantically-joinable   66.666667
# 450  prospect_vertical_30_ac5_av  prospect  semantically-joinable   66.666667
# 451    prospect_both_50_1_ac1_av  prospect  semantically-joinable  100.000000
# 452   prospect_both_50_70_ac3_av  prospect  semantically-joinable   66.666667
# 453        Musicians_semjoinable  Wikidata  semantically-joinable   93.333333
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# 0    100.000000  100.000000      4.920662
# 1     34.782609   50.000000      4.766464
# 2     34.782609   50.000000      4.834251
# 3     69.565217   80.000000     33.917574
# 4     52.173913  100.000000      6.004853
# ..          ...         ...           ...
# 449   50.000000  100.000000     19.324811
# 450   66.666667   66.666667     16.190031
# 451  100.000000  100.000000      3.690933
# 452   66.666667   66.666667     24.956695
# 453   87.500000  100.000000      5.566993
#
#                                            UNI: params       K: F1  \
# 0    {'language_model': 'sdistilroberta', 'similari...  100.000000
# 1    {'language_model': 'sdistilroberta', 'similari...   37.837838
# 2    {'language_model': 'sdistilroberta', 'similari...   37.837838
# 3    {'language_model': 'st5', 'similarity': 0.1, '...   75.000000
# 4    {'language_model': 'sdistilroberta', 'similari...   68.571429
# ..                                                 ...         ...
# 449  {'language_model': 'st5', 'similarity': 0.6, '...   66.666667
# 450  {'language_model': 'st5', 'similarity': 0.5499...   72.727273
# 451  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 452  {'language_model': 'st5', 'similarity': 0.5499...   66.666667
# 453  {'language_model': 'sdistilroberta', 'similari...   93.333333
#
#           K: Re  ...  TopKJoin-K: SUM & AVG   EJoin-K: SUM & AVG  \
# 0    100.000000  ...      66.61141413420947   63.982654399120015
# 1     30.434783  ...     0.1467211765070693  0.14093095682625553
# 2     30.434783  ...
# 3     65.217391  ...
# 4     52.173913  ...
# ..          ...  ...                    ...                  ...
# 449   50.000000  ...
# 450   66.666667  ...
# 451  100.000000  ...
# 452   60.000000  ...
# 453   87.500000  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG        CU: SUM & AVG  \
# 0           379.667373617614        379.667373617614   215.66937309137924
# 1         0.8381178225554392      0.8381178225554392  0.47504267200744327
# 2
# 3
# 4
# ..                       ...                     ...                  ...
# 449
# 450
# 451
# 452
# 453
#
#            CO: SUM & AVG       DB: SUM & AVG      JDM: SUM & AVG  \
# 0     211.83429585498067  451.89064853161904   225.8667252174261
# 1    0.46659536531934065  0.9953538513912313  0.4975038000383835
# 2
# 3
# 4
# ..                   ...                 ...                 ...
# 449
# 450
# 451
# 452
# 453
#
#            SF: SUM & AVG  UNICORN: SUM & AVG
# 0      211.7795502643067  203.94754261040646
# 1    0.46647478031785616  0.4492236621374592
# 2
# 3
# 4
# ..                   ...                 ...
# 449
# 450
# 451
# 452
# 453
#
# [454 rows x 109 columns]

# %%
df[['dataset', 'dataset_type']].value_counts()
# Out:
# dataset   dataset_type
# assays    joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# miller2   joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# prospect  joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# assays    unionable                30
# miller2   unionable                30
# prospect  unionable                30
# Wikidata  joinable                  1
#           semantically-joinable     1
#           unionable                 1
#           view-unionable            1
# dtype: int64

# %%
datasets = df[df['dataset_type'] == dataset_type]
datasets
# Out:
#                         filename   dataset           dataset_type     UNI: F1  \
# 333     assays_both_50_50_ac3_av    assays  semantically-joinable   81.818182
# 334     assays_both_50_30_ac2_av    assays  semantically-joinable   85.714286
# 335     assays_vertical_1_ac1_av    assays  semantically-joinable  100.000000
# 336    assays_vertical_30_ac4_av    assays  semantically-joinable   46.153846
# 337    assays_vertical_50_ac5_av    assays  semantically-joinable   44.444444
# ..                           ...       ...                    ...         ...
# 449   prospect_both_50_30_ac2_av  prospect  semantically-joinable   66.666667
# 450  prospect_vertical_30_ac5_av  prospect  semantically-joinable   66.666667
# 451    prospect_both_50_1_ac1_av  prospect  semantically-joinable  100.000000
# 452   prospect_both_50_70_ac3_av  prospect  semantically-joinable   66.666667
# 453        Musicians_semjoinable  Wikidata  semantically-joinable   93.333333
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# 333   81.818182   81.818182     24.796218
# 334  100.000000   75.000000     23.672441
# 335  100.000000  100.000000      3.164913
# 336   50.000000   42.857143     23.285946
# 337   36.363636   57.142857      4.145791
# ..          ...         ...           ...
# 449   50.000000  100.000000     19.324811
# 450   66.666667   66.666667     16.190031
# 451  100.000000  100.000000      3.690933
# 452   66.666667   66.666667     24.956695
# 453   87.500000  100.000000      5.566993
#
#                                            UNI: params       K: F1  \
# 333  {'language_model': 'st5', 'similarity': 0.1, '...   70.000000
# 334  {'language_model': 'st5', 'similarity': 0.1, '...   85.714286
# 335  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 336  {'language_model': 'st5', 'similarity': 0.65, ...   50.000000
# 337  {'language_model': 'sdistilroberta', 'similari...   44.444444
# ..                                                 ...         ...
# 449  {'language_model': 'st5', 'similarity': 0.6, '...   66.666667
# 450  {'language_model': 'st5', 'similarity': 0.5499...   72.727273
# 451  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 452  {'language_model': 'st5', 'similarity': 0.5499...   66.666667
# 453  {'language_model': 'sdistilroberta', 'similari...   93.333333
#
#           K: Re  ...  TopKJoin-K: SUM & AVG  EJoin-K: SUM & AVG  \
# 333   63.636364  ...
# 334  100.000000  ...
# 335  100.000000  ...
# 336   50.000000  ...
# 337   36.363636  ...
# ..          ...  ...                    ...                 ...
# 449   50.000000  ...
# 450   66.666667  ...
# 451  100.000000  ...
# 452   60.000000  ...
# 453   87.500000  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG  CU: SUM & AVG  \
# 333
# 334
# 335
# 336
# 337
# ..                       ...                     ...            ...
# 449
# 450
# 451
# 452
# 453
#
#      CO: SUM & AVG DB: SUM & AVG  JDM: SUM & AVG  SF: SUM & AVG  \
# 333
# 334
# 335
# 336
# 337
# ..             ...           ...             ...            ...
# 449
# 450
# 451
# 452
# 453
#
#      UNICORN: SUM & AVG
# 333
# 334
# 335
# 336
# 337
# ..                  ...
# 449
# 450
# 451
# 452
# 453
#
# [121 rows x 109 columns]

# %%
f1 = datasets.filter(regex='F1').copy()
f1
# Out:
#         UNI: F1       K: F1  TopKJoin-UNI: F1  EJoin-UNI: F1  TopKJoin-K: F1  \
# 333   81.818182   70.000000         95.652174      95.652174       95.238095
# 334   85.714286   85.714286         76.923077      71.428571       76.923077
# 335  100.000000  100.000000        100.000000     100.000000      100.000000
# 336   46.153846   50.000000         25.000000      37.500000       20.000000
# 337   44.444444   44.444444         58.823529      63.636364       66.666667
# ..          ...         ...               ...            ...             ...
# 449   66.666667   66.666667         83.333333      83.333333       83.333333
# 450   66.666667   72.727273         61.538462      61.538462       76.923077
# 451  100.000000  100.000000        100.000000     100.000000      100.000000
# 452   66.666667   66.666667         85.714286      85.714286       85.714286
# 453   93.333333   93.333333         85.714286      85.714286       76.923077
#
#      EJoin-K: F1  syntactic-UNI: F1  syntactic-K: F1     CU: F1  DB: F1  \
# 333    95.238095          30.769231        30.769231  66.666667     0.0
# 334    76.923077           0.000000         0.000000  42.857143     0.0
# 335   100.000000           0.000000         0.000000  50.000000     0.0
# 336    30.769231           0.000000         0.000000   0.000000     0.0
# 337    80.000000           0.000000         0.000000  30.000000     0.0
# ..           ...                ...              ...        ...     ...
# 449    83.333333           0.000000         0.000000  28.571429     0.0
# 450    76.923077           0.000000         0.000000  71.428571     0.0
# 451   100.000000         100.000000       100.000000  50.000000     0.0
# 452    85.714286           0.000000         0.000000  66.666667     0.0
# 453    76.923077           0.000000         0.000000  82.352941     0.0
#
#         JDM: F1     SF: F1     CO: F1  UNICORN: F1      max F1
# 333   85.714286  88.000000  50.000000    63.999946   95.652174
# 334   50.000000  50.000000  60.000000    39.999960   85.714286
# 335    5.714286   0.000000  50.000000    16.666649  100.000000
# 336    6.000000   5.555556   0.000000    20.408141   50.000000
# 337   32.258065  78.571429  42.857143    48.648604   80.000000
# ..          ...        ...        ...          ...         ...
# 449   83.333333  92.307692  90.909091    59.999940   92.307692
# 450   40.000000  33.333333  60.000000    30.769176   76.923077
# 451  100.000000  22.222222  40.000000    99.999850  100.000000
# 452   86.666667  96.774194  69.565217    58.823477   96.774194
# 453   66.666667  63.157895  76.923077    57.142800   93.333333
#
# [121 rows x 15 columns]

# %%
f1.drop(columns=['max F1'], inplace=True)
f1.rename(columns={'UNI: F1':'SemU', 'K: F1':'SemK', 'TopKJoin-UNI: F1':'SynU', 'TopKJoin-K: F1':'SynK',
                   'EJoin-UNI: F1':'SimU', 'EJoin-K: F1':'SimK',                
                   'syntactic-UNI: F1':'BlU', 'syntactic-K: F1':'BlK',
                   'CU: F1':'CU', 'CO: F1':'CO','DB: F1':'DB', 'JDM: F1':'JDM', 
                   'SF: F1':'SF', 'EmbDI: F1': 'EmbDI', 'UNICORN: F1':'UNC'}, inplace=True)
cols = list(f1.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
f1 = f1[cols]
f1
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 333   81.818182   70.000000   95.652174   95.238095   95.652174   95.238095
# 334   85.714286   85.714286   76.923077   76.923077   71.428571   76.923077
# 335  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 336   46.153846   50.000000   25.000000   20.000000   37.500000   30.769231
# 337   44.444444   44.444444   58.823529   66.666667   63.636364   80.000000
# ..          ...         ...         ...         ...         ...         ...
# 449   66.666667   66.666667   83.333333   83.333333   83.333333   83.333333
# 450   66.666667   72.727273   61.538462   76.923077   61.538462   76.923077
# 451  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 452   66.666667   66.666667   85.714286   85.714286   85.714286   85.714286
# 453   93.333333   93.333333   85.714286   76.923077   85.714286   76.923077
#
#             BlU         BlK         CU   DB         JDM         SF         CO  \
# 333   30.769231   30.769231  66.666667  0.0   85.714286  88.000000  50.000000
# 334    0.000000    0.000000  42.857143  0.0   50.000000  50.000000  60.000000
# 335    0.000000    0.000000  50.000000  0.0    5.714286   0.000000  50.000000
# 336    0.000000    0.000000   0.000000  0.0    6.000000   5.555556   0.000000
# 337    0.000000    0.000000  30.000000  0.0   32.258065  78.571429  42.857143
# ..          ...         ...        ...  ...         ...        ...        ...
# 449    0.000000    0.000000  28.571429  0.0   83.333333  92.307692  90.909091
# 450    0.000000    0.000000  71.428571  0.0   40.000000  33.333333  60.000000
# 451  100.000000  100.000000  50.000000  0.0  100.000000  22.222222  40.000000
# 452    0.000000    0.000000  66.666667  0.0   86.666667  96.774194  69.565217
# 453    0.000000    0.000000  82.352941  0.0   66.666667  63.157895  76.923077
#
#            UNC
# 333  63.999946
# 334  39.999960
# 335  16.666649
# 336  20.408141
# 337  48.648604
# ..         ...
# 449  59.999940
# 450  30.769176
# 451  99.999850
# 452  58.823477
# 453  57.142800
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(f1)
ax.set_title("F-Measure") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_f1')

# %%
f1.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    68.409752   68.680046   71.581209   71.666062   70.846813   72.361434
# std     25.699462   25.323921   27.449170   27.043145   27.466538   26.162371
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     51.612903   53.846154   58.823529   58.333333   57.142857   63.636364
# 50%     66.666667   66.666667   78.260870   77.551020   76.190476   76.923077
# 75%     96.774194   96.774194   95.652174   92.857143   95.238095   92.307692
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    14.059656   14.059656   42.220366    0.091827   43.784374   44.298942
# std     31.208320   31.208320   29.283994    0.711267   33.029529   33.967382
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   19.047619    0.000000   13.157895   13.333333
# 50%      0.000000    0.000000   43.243243    0.000000   34.042553   33.333333
# 75%      5.555556    5.555556   61.538462    0.000000   76.923077   80.000000
# max    100.000000  100.000000   98.039216    5.555556  100.000000   96.969697
#
#                CO         UNC
# count  121.000000  121.000000
# mean    46.783732   46.792876
# std     25.497988   23.774535
# min      0.000000    0.000000
# 25%     33.333333   30.769193
# 50%     48.648649   48.101221
# 75%     62.500000   59.999946
# max    100.000000   99.999933

# %%
re = datasets.filter(regex='Re').copy()
re.rename(columns={'UNI: Re':'SemU', 'K: Re':'SemK', 'TopKJoin-UNI: Re':'SynU', 'TopKJoin-K: Re':'SynK',
                   'EJoin-UNI: Re':'SimU', 'EJoin-K: Re':'SimK',                
                   'syntactic-UNI: Re':'BlU', 'syntactic-K: Re':'BlK',
                   'CU: Re':'CU', 'CO: Re':'CO','DB: Re':'DB', 'JDM: Re':'JDM', 
                   'SF: Re':'SF', 'EmbDI: Re': 'EmbDI', 'UNICORN: Re':'UNC'}, inplace=True)
cols = list(re.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
re = re[cols]
re
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 333   81.818182   63.636364  100.000000   90.909091  100.000000   90.909091
# 334  100.000000  100.000000   83.333333   83.333333   83.333333   83.333333
# 335  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 336   50.000000   50.000000   33.333333   16.666667   50.000000   33.333333
# 337   36.363636   36.363636   45.454545   54.545455   63.636364   72.727273
# ..          ...         ...         ...         ...         ...         ...
# 449   50.000000   50.000000   83.333333   83.333333   83.333333   83.333333
# 450   66.666667   66.666667   66.666667   83.333333   66.666667   83.333333
# 451  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 452   66.666667   60.000000   80.000000   80.000000   80.000000   80.000000
# 453   87.500000   87.500000   75.000000   62.500000   75.000000   62.500000
#
#             BlU         BlK          CU   DB         JDM          SF  \
# 333   18.181818   18.181818   63.636364  0.0   81.818182  100.000000
# 334    0.000000    0.000000   50.000000  0.0   33.333333   33.333333
# 335    0.000000    0.000000  100.000000  0.0  100.000000    0.000000
# 336    0.000000    0.000000    0.000000  0.0   50.000000  100.000000
# 337    0.000000    0.000000   27.272727  0.0   45.454545  100.000000
# ..          ...         ...         ...  ...         ...         ...
# 449    0.000000    0.000000   33.333333  0.0   83.333333  100.000000
# 450    0.000000    0.000000   83.333333  0.0   50.000000   50.000000
# 451  100.000000  100.000000  100.000000  0.0  100.000000  100.000000
# 452    0.000000    0.000000   60.000000  0.0   86.666667  100.000000
# 453    0.000000    0.000000   87.500000  0.0   62.500000   75.000000
#
#              CO        UNC
# 333   36.363636  72.727266
# 334   50.000000  83.333319
# 335  100.000000  99.999900
# 336    0.000000  83.333319
# 337   27.272727  81.818174
# ..          ...        ...
# 449   83.333333  49.999992
# 450   50.000000  33.333328
# 451  100.000000  99.999900
# 452   53.333333  66.666662
# 453   62.500000  49.999994
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(re)
ax.set_title("Recall") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_re')

# %%
re.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    72.477845   70.868395   76.891784   75.470350   78.946039   77.016234
# std     27.001286   26.915292   27.740141   27.416789   25.310110   24.899433
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     53.333333   52.000000   64.000000   63.636364   66.666667   63.636364
# 50%     75.000000   66.666667   84.000000   82.857143   84.000000   81.818182
# 75%    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    12.700995   12.700995   53.255089    0.047226   59.924573   70.990922
# std     30.672955   30.672955   36.214827    0.365794   35.112562   37.897509
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   25.000000    0.000000   27.272727   33.333333
# 50%      0.000000    0.000000   50.000000    0.000000   66.666667  100.000000
# 75%      2.857143    2.857143   93.750000    0.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000    2.857143  100.000000  100.000000
#
#                CO         UNC
# count  121.000000  121.000000
# mean    45.856669   71.859930
# std     31.320476   28.883312
# min      0.000000    0.000000
# 25%     22.857143   59.999996
# 50%     40.000000   74.285712
# 75%     66.666667   99.999900
# max    100.000000   99.999997

# %%
pr = datasets.filter(regex='Pr').copy()
pr.rename(columns={'UNI: Pr':'SemU', 'K: Pr':'SemK', 'TopKJoin-UNI: Pr':'SynU', 'TopKJoin-K: Pr':'SynK',
                   'EJoin-UNI: Pr':'SimU', 'EJoin-K: Pr':'SimK',                
                   'syntactic-UNI: Pr':'BlU', 'syntactic-K: Pr':'BlK',
                   'CU: Pr':'CU', 'CO: Pr':'CO','DB: Pr':'DB', 'JDM: Pr':'JDM', 
                   'SF: Pr':'SF', 'EmbDI: Pr': 'EmbDI', 'UNICORN: Pr':'UNC'}, inplace=True)
cols = list(pr.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
pr = pr[cols]
pr
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 333   81.818182   77.777778   91.666667  100.000000   91.666667  100.000000
# 334   75.000000   75.000000   71.428571   71.428571   62.500000   71.428571
# 335  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 336   42.857143   50.000000   20.000000   25.000000   30.000000   28.571429
# 337   57.142857   57.142857   83.333333   85.714286   63.636364   88.888889
# ..          ...         ...         ...         ...         ...         ...
# 449  100.000000  100.000000   83.333333   83.333333   83.333333   83.333333
# 450   66.666667   80.000000   57.142857   71.428571   57.142857   71.428571
# 451  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 452   66.666667   75.000000   92.307692   92.307692   92.307692   92.307692
# 453  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#        BlU    BlK         CU   DB         JDM          SF          CO  \
# 333  100.0  100.0  70.000000  0.0   90.000000   78.571429   80.000000
# 334    0.0    0.0  37.500000  0.0  100.000000  100.000000   75.000000
# 335    0.0    0.0  33.333333  0.0    2.941176    0.000000   33.333333
# 336    0.0    0.0   0.000000  0.0    3.191489    2.857143    0.000000
# 337    0.0    0.0  33.333333  0.0   25.000000   64.705882  100.000000
# ..     ...    ...        ...  ...         ...         ...         ...
# 449    0.0    0.0  25.000000  0.0   83.333333   85.714286  100.000000
# 450    0.0    0.0  62.500000  0.0   33.333333   25.000000   75.000000
# 451  100.0  100.0  33.333333  0.0  100.000000   12.500000   25.000000
# 452    0.0    0.0  75.000000  0.0   86.666667   93.750000  100.000000
# 453    0.0    0.0  77.777778  0.0   71.428571   54.545455  100.000000
#
#            UNC
# 333  57.142853
# 334  26.315788
# 335   9.090908
# 336  11.627907
# 337  34.615383
# ..         ...
# 449  74.999981
# 450  28.571424
# 451  99.999900
# 452  52.631576
# 453  66.666656
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(pr)
ax.set_title("Precision") 
ax.tick_params(axis='both', labelsize=12)
plt.xticks(rotation=45)
plt.ylim(-1, 101)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_pr')

# %%
pr.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    69.542108   71.936737   73.174030   75.048076   69.868397   74.295431
# std     26.810839   26.321981   28.927583   29.072622   30.280088   29.466777
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     57.142857   61.111111   60.000000   66.666667   52.631579   63.636364
# 50%     72.727273   75.000000   82.142857   83.333333   77.777778   83.333333
# 75%    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    27.134986   27.134986   40.140204    1.652893   44.795016   41.737076
# std     44.520711   44.520711   28.898844   12.802806   36.065414   34.052260
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   15.789474    0.000000   10.000000   10.000000
# 50%      0.000000    0.000000   37.500000    0.000000   35.294118   34.482759
# 75%    100.000000  100.000000   60.000000    0.000000   81.818182   73.333333
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#                CO         UNC
# count  121.000000  121.000000
# mean    65.186031   38.513469
# std     34.385356   23.685741
# min      0.000000    0.000000
# 25%     33.333333   22.580644
# 50%     75.000000   37.209301
# 75%    100.000000   49.999988
# max    100.000000   99.999983

# %%
f1['max_value'] = f1.max(axis=1)
f1
# Out:
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\3926272513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['max_value'] = f1.max(axis=1)
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 333   81.818182   70.000000   95.652174   95.238095   95.652174   95.238095
# 334   85.714286   85.714286   76.923077   76.923077   71.428571   76.923077
# 335  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 336   46.153846   50.000000   25.000000   20.000000   37.500000   30.769231
# 337   44.444444   44.444444   58.823529   66.666667   63.636364   80.000000
# ..          ...         ...         ...         ...         ...         ...
# 449   66.666667   66.666667   83.333333   83.333333   83.333333   83.333333
# 450   66.666667   72.727273   61.538462   76.923077   61.538462   76.923077
# 451  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 452   66.666667   66.666667   85.714286   85.714286   85.714286   85.714286
# 453   93.333333   93.333333   85.714286   76.923077   85.714286   76.923077
#
#             BlU         BlK         CU   DB         JDM         SF         CO  \
# 333   30.769231   30.769231  66.666667  0.0   85.714286  88.000000  50.000000
# 334    0.000000    0.000000  42.857143  0.0   50.000000  50.000000  60.000000
# 335    0.000000    0.000000  50.000000  0.0    5.714286   0.000000  50.000000
# 336    0.000000    0.000000   0.000000  0.0    6.000000   5.555556   0.000000
# 337    0.000000    0.000000  30.000000  0.0   32.258065  78.571429  42.857143
# ..          ...         ...        ...  ...         ...        ...        ...
# 449    0.000000    0.000000  28.571429  0.0   83.333333  92.307692  90.909091
# 450    0.000000    0.000000  71.428571  0.0   40.000000  33.333333  60.000000
# 451  100.000000  100.000000  50.000000  0.0  100.000000  22.222222  40.000000
# 452    0.000000    0.000000  66.666667  0.0   86.666667  96.774194  69.565217
# 453    0.000000    0.000000  82.352941  0.0   66.666667  63.157895  76.923077
#
#            UNC   max_value
# 333  63.999946   95.652174
# 334  39.999960   85.714286
# 335  16.666649  100.000000
# 336  20.408141   50.000000
# 337  48.648604   80.000000
# ..         ...         ...
# 449  59.999940   92.307692
# 450  30.769176   76.923077
# 451  99.999850  100.000000
# 452  58.823477   96.774194
# 453  57.142800   93.333333
#
# [121 rows x 15 columns]

# %%
f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
#f1['EMBDI_DFT'] = 1- f1['EmbDI']/f1['max_value']
f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
f1
# Out:
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_7280\1342584874.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 333   81.818182   70.000000   95.652174   95.238095   95.652174   95.238095
# 334   85.714286   85.714286   76.923077   76.923077   71.428571   76.923077
# 335  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 336   46.153846   50.000000   25.000000   20.000000   37.500000   30.769231
# 337   44.444444   44.444444   58.823529   66.666667   63.636364   80.000000
# ..          ...         ...         ...         ...         ...         ...
# 449   66.666667   66.666667   83.333333   83.333333   83.333333   83.333333
# 450   66.666667   72.727273   61.538462   76.923077   61.538462   76.923077
# 451  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 452   66.666667   66.666667   85.714286   85.714286   85.714286   85.714286
# 453   93.333333   93.333333   85.714286   76.923077   85.714286   76.923077
#
#             BlU         BlK         CU   DB  ...  SimU_DFT  SimK_DFT  \
# 333   30.769231   30.769231  66.666667  0.0  ...  0.000000  0.004329
# 334    0.000000    0.000000  42.857143  0.0  ...  0.166667  0.102564
# 335    0.000000    0.000000  50.000000  0.0  ...  0.000000  0.000000
# 336    0.000000    0.000000   0.000000  0.0  ...  0.250000  0.384615
# 337    0.000000    0.000000  30.000000  0.0  ...  0.204545  0.000000
# ..          ...         ...        ...  ...  ...       ...       ...
# 449    0.000000    0.000000  28.571429  0.0  ...  0.097222  0.097222
# 450    0.000000    0.000000  71.428571  0.0  ...  0.200000  0.000000
# 451  100.000000  100.000000  50.000000  0.0  ...  0.000000  0.000000
# 452    0.000000    0.000000  66.666667  0.0  ...  0.114286  0.114286
# 453    0.000000    0.000000  82.352941  0.0  ...  0.081633  0.175824
#
#       BlU_DFT   BlK_DFT    CU_DFT    CO_DFT  DB_DFT   JDM_DFT    SF_DFT  \
# 333  0.678322  0.678322  0.303030  0.477273     1.0  0.103896  0.080000
# 334  1.000000  1.000000  0.500000  0.300000     1.0  0.416667  0.416667
# 335  1.000000  1.000000  0.500000  0.500000     1.0  0.942857  1.000000
# 336  1.000000  1.000000  1.000000  1.000000     1.0  0.880000  0.888889
# 337  1.000000  1.000000  0.625000  0.464286     1.0  0.596774  0.017857
# ..        ...       ...       ...       ...     ...       ...       ...
# 449  1.000000  1.000000  0.690476  0.015152     1.0  0.097222  0.000000
# 450  1.000000  1.000000  0.071429  0.220000     1.0  0.480000  0.566667
# 451  0.000000  0.000000  0.500000  0.600000     1.0  0.000000  0.777778
# 452  1.000000  1.000000  0.311111  0.281159     1.0  0.104444  0.000000
# 453  1.000000  1.000000  0.117647  0.175824     1.0  0.285714  0.323308
#
#       UNC_DFT
# 333  0.330910
# 334  0.533334
# 335  0.833334
# 336  0.591837
# 337  0.391892
# ..        ...
# 449  0.350001
# 450  0.600001
# 451  0.000001
# 452  0.392157
# 453  0.387756
#
# [121 rows x 29 columns]

# %%
dft = f1.filter(regex='DFT').copy()
dft
# Out:
#      SemU_DFT  SemK_DFT  SynU_DFT  SynK_DFT  SimU_DFT  SimK_DFT   BlU_DFT  \
# 333  0.144628  0.268182  0.000000  0.004329  0.000000  0.004329  0.678322
# 334  0.000000  0.000000  0.102564  0.102564  0.166667  0.102564  1.000000
# 335  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 336  0.076923  0.000000  0.500000  0.600000  0.250000  0.384615  1.000000
# 337  0.444444  0.444444  0.264706  0.166667  0.204545  0.000000  1.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 449  0.277778  0.277778  0.097222  0.097222  0.097222  0.097222  1.000000
# 450  0.133333  0.054545  0.200000  0.000000  0.200000  0.000000  1.000000
# 451  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 452  0.311111  0.311111  0.114286  0.114286  0.114286  0.114286  1.000000
# 453  0.000000  0.000000  0.081633  0.175824  0.081633  0.175824  1.000000
#
#       BlK_DFT    CU_DFT    CO_DFT  DB_DFT   JDM_DFT    SF_DFT   UNC_DFT
# 333  0.678322  0.303030  0.477273     1.0  0.103896  0.080000  0.330910
# 334  1.000000  0.500000  0.300000     1.0  0.416667  0.416667  0.533334
# 335  1.000000  0.500000  0.500000     1.0  0.942857  1.000000  0.833334
# 336  1.000000  1.000000  1.000000     1.0  0.880000  0.888889  0.591837
# 337  1.000000  0.625000  0.464286     1.0  0.596774  0.017857  0.391892
# ..        ...       ...       ...     ...       ...       ...       ...
# 449  1.000000  0.690476  0.015152     1.0  0.097222  0.000000  0.350001
# 450  1.000000  0.071429  0.220000     1.0  0.480000  0.566667  0.600001
# 451  0.000000  0.500000  0.600000     1.0  0.000000  0.777778  0.000001
# 452  1.000000  0.311111  0.281159     1.0  0.104444  0.000000  0.392157
# 453  1.000000  0.117647  0.175824     1.0  0.285714  0.323308  0.387756
#
# [121 rows x 14 columns]

# %%
dft.describe()
# Out:
#          SemU_DFT    SemK_DFT    SynU_DFT    SynK_DFT    SimU_DFT    SimK_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.201010    0.197041    0.158597    0.156313    0.168886    0.143960
# std      0.236708    0.234306    0.246375    0.245229    0.244584    0.239229
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.133333    0.107438    0.045455    0.049580    0.083333    0.047619
# 75%      0.323077    0.314685    0.220000    0.200000    0.205128    0.167619
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           BlU_DFT     BlK_DFT      CU_DFT      CO_DFT      DB_DFT     JDM_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.856189    0.856189    0.504573    0.465094    0.999001    0.500278
# std      0.314544    0.314544    0.305739    0.269438    0.007737    0.340175
# min      0.000000    0.000000    0.000000    0.000000    0.938095    0.000000
# 25%      0.931070    0.931070    0.282051    0.281159    1.000000    0.133333
# 50%      1.000000    1.000000    0.500000    0.450000    1.000000    0.560000
# 75%      1.000000    1.000000    0.714286    0.600000    1.000000    0.847619
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            SF_DFT     UNC_DFT
# count  121.000000  121.000000
# mean     0.485456    0.460160
# std      0.355333    0.242864
# min      0.000000    0.000000
# 25%      0.098837    0.330358
# 50%      0.507042    0.435898
# 75%      0.814815    0.558491
# max      1.000000    1.000000

# %%
dft.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
rt = datasets.filter(regex='runtime').copy()
rt.rename(columns={'UNI: runtime':'SemU', 'K: runtime':'SemK', 'TopKJoin-UNI: runtime':'SynU', 'TopKJoin-K: runtime':'SynK',
                   'EJoin-UNI: runtime':'SimU', 'EJoin-K: runtime':'SimK',                
                   'syntactic-UNI: runtime':'BlU', 'syntactic-K: runtime':'BlK',
                   'CU: runtime':'CU', 'CO: runtime':'CO','DB: runtime':'DB', 'JDM: runtime':'JDM', 
                   'SF: runtime':'SF', 'EmbDI: runtime': 'EmbDI', 'UNICORN: runtime':'UNC'}, inplace=True)
cols = list(rt.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
rt = rt[cols]
rt
# Out:
#           SemU       SemK      SynU      SynK      SimU      SimK  \
# 333  24.796218  23.608443  0.007992  0.061428  0.007109  0.061164
# 334  23.672441  23.797705  0.006266  0.048105  0.006064  0.050698
# 335   3.164913   3.215134  0.006521  0.039996  0.005685  0.050093
# 336  23.285946  23.344535  0.009505  0.049773  0.008338  0.063312
# 337   4.145791   4.205208  0.009474  0.065701  0.009958  0.075641
# ..         ...        ...       ...       ...       ...       ...
# 449  19.324811  19.395190  0.005739  0.047769  0.005190  0.047463
# 450  16.190031  16.963440  0.006639  0.046935  0.005465  0.045679
# 451   3.690933   3.745447  0.005565  0.037319  0.004440  0.036557
# 452  24.956695  25.334997  0.008111  0.067159  0.006979  0.067308
# 453   5.566993   5.635441  0.006890  0.053383  0.005858  0.055071
#
#                     BlU                 BlK         CU        DB       JDM  \
# 333  0.0084414929151535  0.0083821006119251  24.433036  5.680223  5.155451
# 334                                          20.594549  4.199353  4.205517
# 335  0.0144440680742263   0.014240626245737  29.270068  4.634823  4.464461
# 336                                          29.303172  4.568242  5.086814
# 337                                          38.308699  5.320986  4.229085
# ..                  ...                 ...        ...       ...       ...
# 449                                          21.543116  4.406943  4.398714
# 450                                          24.419959  4.390861  4.419072
# 451  0.0063579455018043  0.0063489824533462  24.046688  4.611887  4.179476
# 452                                          23.332710  4.753416  4.315215
# 453                                          24.772440  4.526592  4.389801
#
#            SF        CO       UNC
# 333  2.241221  0.963622  1.374430
# 334  1.303114  0.920609  0.991277
# 335  1.339865  1.009417  0.686791
# 336  1.449374  1.097037  0.994205
# 337  2.337475  0.942500  1.376900
# ..        ...       ...       ...
# 449  1.067303  0.945920  0.982065
# 450  1.527523  0.978473  0.945837
# 451  0.633055  0.945822  0.639126
# 452  1.818517  0.944732  1.644380
# 453  0.925068  0.946712  0.950853
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(rt)
ax.set_title("Run-time") 
ax.tick_params(axis='both', labelsize=12)
plt.yscale('log')
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_rt')

# %%
rt.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    19.606560   19.274289    0.011328    0.066360    0.009769    0.073211
# std     14.520169   14.588063    0.006497    0.026179    0.005565    0.034271
# min      2.909645    2.958733    0.004807    0.035614    0.004169    0.034475
# 25%      4.912507    4.749612    0.006760    0.047030    0.005783    0.048382
# 50%     20.444770   19.655914    0.008892    0.060909    0.007779    0.063312
# 75%     29.497779   29.088714    0.013627    0.077067    0.012060    0.084263
# max     62.436100   62.579557    0.030991    0.140317    0.027286    0.209518
#
#                CU          DB         JDM          SF          CO         UNC
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    54.896882    4.927206    4.476407    4.334521    1.052287    2.871854
# std     46.623459    0.435530    0.272947    5.372702    0.154278    2.750253
# min     18.170473    3.945539    3.856321    0.282872    0.880198    0.635629
# 25%     24.433036    4.575581    4.341165    1.067303    0.941480    0.982065
# 50%     32.406517    4.882641    4.426106    1.849646    0.979955    1.379636
# 75%     73.338962    5.320986    4.515131    4.743862    1.150968    3.394578
# max    233.686976    6.122486    5.251880   23.345903    1.475086    9.324823
