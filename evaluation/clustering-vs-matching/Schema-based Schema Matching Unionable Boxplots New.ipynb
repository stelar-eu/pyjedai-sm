# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid") 

dataset_type = 'unionable'

main_dir = 'C:/Users/G_A.Papadakis/OneDrive - Public Power Corporation S.A/Schema Matching/Valentine/'
df = pd.read_csv(main_dir + 'results_only_schema_with_re_pr.csv')
df
# Out:
#                         filename   dataset           dataset_type     UNI: F1  \
# 0     assays_horizontal_0_ac1_av    assays              unionable  100.000000
# 1    assays_horizontal_50_ac5_av    assays              unionable   41.025641
# 2    assays_horizontal_50_ac5_ev    assays              unionable   41.025641
# 3     assays_horizontal_0_ac2_ev    assays              unionable   74.418605
# 4    assays_horizontal_50_ac2_av    assays              unionable   68.571429
# ..                           ...       ...                    ...         ...
# 449   prospect_both_50_30_ac2_av  prospect  semantically-joinable   66.666667
# 450  prospect_vertical_30_ac5_av  prospect  semantically-joinable   66.666667
# 451    prospect_both_50_1_ac1_av  prospect  semantically-joinable  100.000000
# 452   prospect_both_50_70_ac3_av  prospect  semantically-joinable   66.666667
# 453        Musicians_semjoinable  Wikidata  semantically-joinable   93.333333
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# 0    100.000000  100.000000      4.920662
# 1     34.782609   50.000000      4.766464
# 2     34.782609   50.000000      4.834251
# 3     69.565217   80.000000     33.917574
# 4     52.173913  100.000000      6.004853
# ..          ...         ...           ...
# 449   50.000000  100.000000     19.324811
# 450   66.666667   66.666667     16.190031
# 451  100.000000  100.000000      3.690933
# 452   66.666667   66.666667     24.956695
# 453   87.500000  100.000000      5.566993
#
#                                            UNI: params       K: F1  \
# 0    {'language_model': 'sdistilroberta', 'similari...  100.000000
# 1    {'language_model': 'sdistilroberta', 'similari...   37.837838
# 2    {'language_model': 'sdistilroberta', 'similari...   37.837838
# 3    {'language_model': 'st5', 'similarity': 0.1, '...   75.000000
# 4    {'language_model': 'sdistilroberta', 'similari...   68.571429
# ..                                                 ...         ...
# 449  {'language_model': 'st5', 'similarity': 0.6, '...   66.666667
# 450  {'language_model': 'st5', 'similarity': 0.5499...   72.727273
# 451  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 452  {'language_model': 'st5', 'similarity': 0.5499...   66.666667
# 453  {'language_model': 'sdistilroberta', 'similari...   93.333333
#
#           K: Re  ...  TopKJoin-K: SUM & AVG   EJoin-K: SUM & AVG  \
# 0    100.000000  ...      66.61141413420947   63.982654399120015
# 1     30.434783  ...     0.1467211765070693  0.14093095682625553
# 2     30.434783  ...
# 3     65.217391  ...
# 4     52.173913  ...
# ..          ...  ...                    ...                  ...
# 449   50.000000  ...
# 450   66.666667  ...
# 451  100.000000  ...
# 452   60.000000  ...
# 453   87.500000  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG        CU: SUM & AVG  \
# 0           379.667373617614        379.667373617614   215.66937309137924
# 1         0.8381178225554392      0.8381178225554392  0.47504267200744327
# 2
# 3
# 4
# ..                       ...                     ...                  ...
# 449
# 450
# 451
# 452
# 453
#
#            CO: SUM & AVG       DB: SUM & AVG      JDM: SUM & AVG  \
# 0     211.83429585498067  451.89064853161904   225.8667252174261
# 1    0.46659536531934065  0.9953538513912313  0.4975038000383835
# 2
# 3
# 4
# ..                   ...                 ...                 ...
# 449
# 450
# 451
# 452
# 453
#
#            SF: SUM & AVG  UNICORN: SUM & AVG
# 0      211.7795502643067  203.94754261040646
# 1    0.46647478031785616  0.4492236621374592
# 2
# 3
# 4
# ..                   ...                 ...
# 449
# 450
# 451
# 452
# 453
#
# [454 rows x 109 columns]

# %%
df[['dataset', 'dataset_type']].value_counts()
# Out:
# dataset   dataset_type
# assays    joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# miller2   joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# prospect  joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# assays    unionable                30
# miller2   unionable                30
# prospect  unionable                30
# Wikidata  joinable                  1
#           semantically-joinable     1
#           unionable                 1
#           view-unionable            1
# dtype: int64

# %%
datasets = df[df['dataset_type'] == dataset_type]
datasets
# Out:
#                           filename   dataset dataset_type     UNI: F1  \
# 0       assays_horizontal_0_ac1_av    assays    unionable  100.000000
# 1      assays_horizontal_50_ac5_av    assays    unionable   41.025641
# 2      assays_horizontal_50_ac5_ev    assays    unionable   41.025641
# 3       assays_horizontal_0_ac2_ev    assays    unionable   74.418605
# 4      assays_horizontal_50_ac2_av    assays    unionable   68.571429
# ..                             ...       ...          ...         ...
# 86    prospect_horizontal_0_ac4_ev  prospect    unionable   68.292683
# 87    prospect_horizontal_0_ac3_ev  prospect    unionable   71.428571
# 88  prospect_horizontal_100_ac2_av  prospect    unionable   63.414634
# 89    prospect_horizontal_0_ac5_ev  prospect    unionable   73.684211
# 90             Musicians_unionable  Wikidata    unionable   97.435897
#
#        UNI: Re     UNI: Pr  UNI: runtime  \
# 0   100.000000  100.000000      4.920662
# 1    34.782609   50.000000      4.766464
# 2    34.782609   50.000000      4.834251
# 3    69.565217   80.000000     33.917574
# 4    52.173913  100.000000      6.004853
# ..         ...         ...           ...
# 86   63.636364   73.684211     32.056778
# 87   68.181818   75.000000     27.197157
# 88   59.090909   68.421053     28.655153
# 89   63.636364   87.500000     24.717952
# 90   95.000000  100.000000     27.569060
#
#                                           UNI: params       K: F1       K: Re  \
# 0   {'language_model': 'sdistilroberta', 'similari...  100.000000  100.000000
# 1   {'language_model': 'sdistilroberta', 'similari...   37.837838   30.434783
# 2   {'language_model': 'sdistilroberta', 'similari...   37.837838   30.434783
# 3   {'language_model': 'st5', 'similarity': 0.1, '...   75.000000   65.217391
# 4   {'language_model': 'sdistilroberta', 'similari...   68.571429   52.173913
# ..                                                ...         ...         ...
# 86  {'language_model': 'st5', 'similarity': 0.1, '...   73.684211   63.636364
# 87  {'language_model': 'st5', 'similarity': 0.1, '...   66.666667   54.545455
# 88  {'language_model': 'st5', 'similarity': 0.1, '...   66.666667   59.090909
# 89  {'language_model': 'st5', 'similarity': 0.5499...   70.270270   59.090909
# 90  {'language_model': 'st5', 'similarity': 0.1, '...   94.736842   90.000000
#
#     ...  TopKJoin-K: SUM & AVG   EJoin-K: SUM & AVG syntactic-UNI: SUM & AVG  \
# 0   ...      66.61141413420947   63.982654399120015         379.667373617614
# 1   ...     0.1467211765070693  0.14093095682625553       0.8381178225554392
# 2   ...
# 3   ...
# 4   ...
# ..  ...                    ...                  ...                      ...
# 86  ...
# 87  ...
# 88  ...
# 89  ...
# 90  ...
#
#     syntactic-K: SUM & AVG        CU: SUM & AVG        CO: SUM & AVG  \
# 0         379.667373617614   215.66937309137924   211.83429585498067
# 1       0.8381178225554392  0.47504267200744327  0.46659536531934065
# 2
# 3
# 4
# ..                     ...                  ...                  ...
# 86
# 87
# 88
# 89
# 90
#
#          DB: SUM & AVG      JDM: SUM & AVG        SF: SUM & AVG  \
# 0   451.89064853161904   225.8667252174261    211.7795502643067
# 1   0.9953538513912313  0.4975038000383835  0.46647478031785616
# 2
# 3
# 4
# ..                 ...                 ...                  ...
# 86
# 87
# 88
# 89
# 90
#
#     UNICORN: SUM & AVG
# 0   203.94754261040646
# 1   0.4492236621374592
# 2
# 3
# 4
# ..                 ...
# 86
# 87
# 88
# 89
# 90
#
# [91 rows x 109 columns]

# %%
f1 = datasets.filter(regex='F1').copy()
f1 = f1.astype('float64')
f1
# Out:
#        UNI: F1       K: F1  TopKJoin-UNI: F1  EJoin-UNI: F1  TopKJoin-K: F1  \
# 0   100.000000  100.000000         97.777778     100.000000       97.777778
# 1    41.025641   37.837838         48.484848      75.555556       52.941176
# 2    41.025641   37.837838         48.484848      75.555556       52.941176
# 3    74.418605   75.000000         81.818182      80.000000       80.952381
# 4    68.571429   68.571429         79.069767      74.418605       80.000000
# ..         ...         ...               ...            ...             ...
# 86   68.292683   73.684211         82.926829      82.926829       76.923077
# 87   71.428571   66.666667         95.238095      95.238095       90.000000
# 88   63.414634   66.666667         90.476190      90.476190       85.000000
# 89   73.684211   70.270270         95.238095      95.238095       90.000000
# 90   97.435897   94.736842         91.891892      91.891892       88.888889
#
#     EJoin-K: F1  syntactic-UNI: F1  syntactic-K: F1      CU: F1     DB: F1  \
# 0    100.000000          97.777778        97.777778  100.000000   0.000000
# 1     80.952381          16.000000        16.000000   52.631579   0.000000
# 2     80.952381          16.000000        16.000000   52.631579   0.000000
# 3     75.000000           0.000000         0.000000   43.902439   0.000000
# 4     73.684211           0.000000         0.000000   40.000000   0.000000
# ..          ...                ...              ...         ...        ...
# 86    73.684211           0.000000         0.000000   20.000000   0.000000
# 87    87.179487           0.000000         0.000000   71.794872   0.000000
# 88    82.051282           0.000000         0.000000   35.897436   0.000000
# 89    87.179487           0.000000         0.000000   50.000000   0.000000
# 90    78.787879          26.086957        26.086957   89.473684  26.086957
#
#       JDM: F1      SF: F1     CO: F1  UNICORN: F1      max F1
# 0   56.250000   61.904762  64.705882    60.526272  100.000000
# 1   28.571429   36.842105  22.222222    52.173867   80.952381
# 2   28.571429   36.842105  15.384615    52.173867   80.952381
# 3   16.000000   16.000000  45.161290    29.787196   81.818182
# 4   16.000000   16.000000  45.161290    32.911350   80.000000
# ..        ...         ...        ...          ...         ...
# 86  12.765957   10.000000  35.714286    73.469335   82.926829
# 87  88.888889  100.000000  62.500000    51.162738  100.000000
# 88  81.632653   90.909091  62.500000    69.767389   90.909091
# 89  39.215686   42.105263  53.333333    46.153796   95.238095
# 90  60.000000   86.486486  51.851852    63.157842   97.435897
#
# [91 rows x 15 columns]

# %%
f1.drop(columns=['max F1'], inplace=True)
f1.rename(columns={'UNI: F1':'SemU', 'K: F1':'SemK', 'TopKJoin-UNI: F1':'SynU', 'TopKJoin-K: F1':'SynK',
                   'EJoin-UNI: F1':'SimU', 'EJoin-K: F1':'SimK',                
                   'syntactic-UNI: F1':'BlU', 'syntactic-K: F1':'BlK',
                   'CU: F1':'CU', 'CO: F1':'CO','DB: F1':'DB', 'JDM: F1':'JDM', 
                   'SF: F1':'SF', 'EmbDI: F1': 'EmbDI', 'UNICORN: F1':'UNC'}, inplace=True)
cols = list(f1.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
f1 = f1[cols]
f1
# Out:
#           SemU        SemK       SynU       SynK        SimU        SimK  \
# 0   100.000000  100.000000  97.777778  97.777778  100.000000  100.000000
# 1    41.025641   37.837838  48.484848  52.941176   75.555556   80.952381
# 2    41.025641   37.837838  48.484848  52.941176   75.555556   80.952381
# 3    74.418605   75.000000  81.818182  80.952381   80.000000   75.000000
# 4    68.571429   68.571429  79.069767  80.000000   74.418605   73.684211
# ..         ...         ...        ...        ...         ...         ...
# 86   68.292683   73.684211  82.926829  76.923077   82.926829   73.684211
# 87   71.428571   66.666667  95.238095  90.000000   95.238095   87.179487
# 88   63.414634   66.666667  90.476190  85.000000   90.476190   82.051282
# 89   73.684211   70.270270  95.238095  90.000000   95.238095   87.179487
# 90   97.435897   94.736842  91.891892  88.888889   91.891892   78.787879
#
#           BlU        BlK          CU         DB        JDM          SF  \
# 0   97.777778  97.777778  100.000000   0.000000  56.250000   61.904762
# 1   16.000000  16.000000   52.631579   0.000000  28.571429   36.842105
# 2   16.000000  16.000000   52.631579   0.000000  28.571429   36.842105
# 3    0.000000   0.000000   43.902439   0.000000  16.000000   16.000000
# 4    0.000000   0.000000   40.000000   0.000000  16.000000   16.000000
# ..        ...        ...         ...        ...        ...         ...
# 86   0.000000   0.000000   20.000000   0.000000  12.765957   10.000000
# 87   0.000000   0.000000   71.794872   0.000000  88.888889  100.000000
# 88   0.000000   0.000000   35.897436   0.000000  81.632653   90.909091
# 89   0.000000   0.000000   50.000000   0.000000  39.215686   42.105263
# 90  26.086957  26.086957   89.473684  26.086957  60.000000   86.486486
#
#            CO        UNC
# 0   64.705882  60.526272
# 1   22.222222  52.173867
# 2   15.384615  52.173867
# 3   45.161290  29.787196
# 4   45.161290  32.911350
# ..        ...        ...
# 86  35.714286  73.469335
# 87  62.500000  51.162738
# 88  62.500000  69.767389
# 89  53.333333  46.153796
# 90  51.851852  63.157842
#
# [91 rows x 14 columns]

# %%
ax = sns.boxplot(f1)
ax.set_title("F-Measure") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_f1')

# %%
f1.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000   91.000000
# mean    72.748320   69.791164   85.006441   82.748073   87.904709   83.516127
# std     17.277005   18.388607   18.181588   17.072319   11.204819   11.577762
# min     41.025641   37.837838   27.777778   31.250000   51.162791   53.658537
# 25%     62.476548   59.459459   81.818182   78.759398   81.318681   76.190476
# 50%     71.428571   68.292683   90.909091   87.804878   88.888889   81.081081
# 75%     81.684982   77.485929   97.777778   93.023256   97.777778   93.023256
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU         DB        JDM          SF  \
# count   91.000000   91.000000   91.000000  91.000000  91.000000   91.000000
# mean    18.298329   18.298329   57.572540   0.714773  48.573942   61.512494
# std     32.759765   32.759765   29.195114   3.071733  29.781809   37.339395
# min      0.000000    0.000000    0.000000   0.000000   7.575758    0.000000
# 25%      0.000000    0.000000   38.243728   0.000000  16.000000   31.818182
# 50%      0.000000    0.000000   52.631579   0.000000  39.506173   61.904762
# 75%     16.000000   16.000000   73.170732   0.000000  76.775510  100.000000
# max    100.000000  100.000000  100.000000  26.086957  90.196078  100.000000
#
#               CO        UNC
# count  91.000000  91.000000
# mean   47.267506  55.995906
# std    18.988700  15.536788
# min     0.000000  24.074040
# 25%    33.854167  46.153796
# 50%    51.612903  57.599951
# 75%    62.500000  63.030509
# max    81.081081  93.616967

# %%
re = datasets.filter(regex='Re').copy()
re.rename(columns={'UNI: Re':'SemU', 'K: Re':'SemK', 'TopKJoin-UNI: Re':'SynU', 'TopKJoin-K: Re':'SynK',
                   'EJoin-UNI: Re':'SimU', 'EJoin-K: Re':'SimK',                
                   'syntactic-UNI: Re':'BlU', 'syntactic-K: Re':'BlK',
                   'CU: Re':'CU', 'CO: Re':'CO','DB: Re':'DB', 'JDM: Re':'JDM', 
                   'SF: Re':'SF', 'EmbDI: Re': 'EmbDI', 'UNICORN: Re':'UNC'}, inplace=True)
cols = list(re.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
re = re[cols]
re
# Out:
#           SemU        SemK       SynU       SynK        SimU        SimK  \
# 0   100.000000  100.000000  95.652174  95.652174  100.000000  100.000000
# 1    34.782609   30.434783  34.782609  39.130435   73.913043   73.913043
# 2    34.782609   30.434783  34.782609  39.130435   73.913043   73.913043
# 3    69.565217   65.217391  78.260870  73.913043   78.260870   65.217391
# 4    52.173913   52.173913  73.913043  69.565217   69.565217   60.869565
# ..         ...         ...        ...        ...         ...         ...
# 86   63.636364   63.636364  77.272727  68.181818   77.272727   63.636364
# 87   68.181818   54.545455  90.909091  81.818182   90.909091   77.272727
# 88   59.090909   59.090909  86.363636  77.272727   86.363636   72.727273
# 89   63.636364   59.090909  90.909091  81.818182   90.909091   77.272727
# 90   95.000000   90.000000  85.000000  80.000000   85.000000   65.000000
#
#           BlU        BlK          CU    DB        JDM          SF         CO  \
# 0   95.652174  95.652174  100.000000   0.0  78.260870   56.521739  47.826087
# 1    8.695652   8.695652   43.478261   0.0  30.434783   30.434783  13.043478
# 2    8.695652   8.695652   43.478261   0.0  30.434783   30.434783   8.695652
# 3    0.000000   0.000000   39.130435   0.0   8.695652    8.695652  30.434783
# 4    0.000000   0.000000   34.782609   0.0   8.695652    8.695652  30.434783
# ..        ...        ...         ...   ...        ...         ...        ...
# 86   0.000000   0.000000   18.181818   0.0  13.636364    9.090909  22.727273
# 87   0.000000   0.000000   63.636364   0.0  90.909091  100.000000  45.454545
# 88   0.000000   0.000000   31.818182   0.0  90.909091   90.909091  45.454545
# 89   0.000000   0.000000   40.909091   0.0  45.454545   36.363636  36.363636
# 90  15.000000  15.000000   85.000000  15.0  60.000000   80.000000  35.000000
#
#           UNC
# 0   99.999996
# 1   78.260866
# 2   78.260866
# 3   60.869563
# 4   56.521737
# ..        ...
# 86  81.818178
# 87  49.999998
# 88  68.181815
# 89  54.545452
# 90  59.999997
#
# [91 rows x 14 columns]

# %%
ax = sns.boxplot(re)
ax.set_title("Recall") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_re')

# %%
re.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000   91.000000
# mean    66.626711   60.877290   79.930773   75.416476   84.618710   75.796024
# std     20.221626   21.962746   21.428936   20.227897   12.612936   14.952148
# min     34.782609   30.434783   21.739130   21.739130   47.826087   47.826087
# 25%     52.557545   47.826087   76.470588   68.181818   75.191816   64.852941
# 50%     63.636364   56.521739   88.235294   80.392157   86.274510   73.913043
# 75%     75.891266   68.181818   95.652174   86.956522   95.652174   86.956522
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU         DB         JDM          SF  \
# count   91.000000   91.000000   91.000000  91.000000   91.000000   91.000000
# mean    15.832373   15.832373   53.331626   0.384990   54.569284   62.106214
# std     32.529007   32.529007   29.942998   1.728399   29.359498   38.233170
# min      0.000000    0.000000    0.000000   0.000000    8.695652    0.000000
# 25%      0.000000    0.000000   33.333333   0.000000   27.962489   27.450980
# 50%      0.000000    0.000000   43.478261   0.000000   58.823529   76.470588
# 75%      8.695652    8.695652   66.666667   0.000000   81.818182  100.000000
# max    100.000000  100.000000  100.000000  15.000000  100.000000  100.000000
#
#               CO        UNC
# count  91.000000  91.000000
# mean   33.397894  73.374091
# std    16.294497  16.811691
# min     0.000000  40.909089
# 25%    22.147950  60.869563
# 50%    34.782609  70.588234
# 75%    45.454545  84.313724
# max    68.181818  99.999998

# %%
pr = datasets.filter(regex='Pr').copy()
pr.rename(columns={'UNI: Pr':'SemU', 'K: Pr':'SemK', 'TopKJoin-UNI: Pr':'SynU', 'TopKJoin-K: Pr':'SynK',
                   'EJoin-UNI: Pr':'SimU', 'EJoin-K: Pr':'SimK',                
                   'syntactic-UNI: Pr':'BlU', 'syntactic-K: Pr':'BlK',
                   'CU: Pr':'CU', 'CO: Pr':'CO','DB: Pr':'DB', 'JDM: Pr':'JDM', 
                   'SF: Pr':'SF', 'EmbDI: Pr': 'EmbDI', 'UNICORN: Pr':'UNC'}, inplace=True)
cols = list(pr.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
pr = pr[cols]
pr
# Out:
#           SemU        SemK        SynU        SynK        SimU        SimK  \
# 0   100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1    50.000000   50.000000   80.000000   81.818182   77.272727   89.473684
# 2    50.000000   50.000000   80.000000   81.818182   77.272727   89.473684
# 3    80.000000   88.235294   85.714286   89.473684   81.818182   88.235294
# 4   100.000000  100.000000   85.000000   94.117647   80.000000   93.333333
# ..         ...         ...         ...         ...         ...         ...
# 86   73.684211   87.500000   89.473684   88.235294   89.473684   87.500000
# 87   75.000000   85.714286  100.000000  100.000000  100.000000  100.000000
# 88   68.421053   76.470588   95.000000   94.444444   95.000000   94.117647
# 89   87.500000   86.666667  100.000000  100.000000  100.000000  100.000000
# 90  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#       BlU    BlK          CU     DB         JDM          SF          CO  \
# 0   100.0  100.0  100.000000    0.0   43.902439   68.421053  100.000000
# 1   100.0  100.0   66.666667    0.0   26.923077   46.666667   75.000000
# 2   100.0  100.0   66.666667    0.0   26.923077   46.666667   66.666667
# 3     0.0    0.0   50.000000    0.0  100.000000  100.000000   87.500000
# 4     0.0    0.0   47.058824    0.0  100.000000  100.000000   87.500000
# ..    ...    ...         ...    ...         ...         ...         ...
# 86    0.0    0.0   22.222222    0.0   12.000000   11.111111   83.333333
# 87    0.0    0.0   82.352941    0.0   86.956522  100.000000  100.000000
# 88    0.0    0.0   41.176471    0.0   74.074074   90.909091  100.000000
# 89    0.0    0.0   64.285714    0.0   34.482759   50.000000  100.000000
# 90  100.0  100.0   94.444444  100.0   60.000000   94.117647  100.000000
#
#           UNC
# 0   43.396226
# 1   39.130434
# 2   39.130434
# 3   19.718310
# 4   23.214285
# ..        ...
# 86  66.666664
# 87  52.380950
# 88  71.428568
# 89  39.999999
# 90  66.666663
#
# [91 rows x 14 columns]

# %%
ax = sns.boxplot(pr)
ax.set_title("Precision") 
ax.tick_params(axis='both', labelsize=12)
plt.xticks(rotation=45)
plt.ylim(-1, 101)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_pr')

# %%
pr.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000   91.000000
# mean    81.495225   84.332597   92.726763   93.768921   91.735897   94.098398
# std     13.696764   13.291635   11.502725   10.408116   10.305946    8.718298
# min     50.000000   50.000000   38.461538   54.545455   55.000000   61.111111
# 25%     75.000000   78.571429   89.791667   93.933824   88.680851   90.826331
# 50%     80.000000   86.666667   97.297297   97.872340   95.121951   97.222222
# 75%     92.916667   93.750000  100.000000  100.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000   91.000000
# mean    48.351648   48.351648   64.422362    9.890110   52.725948   69.543550
# std     50.249682   50.249682   28.279612   30.018309   31.977317   35.172192
# min      0.000000    0.000000    0.000000    0.000000    4.192872    0.000000
# 25%      0.000000    0.000000   44.097222    0.000000   26.923077   46.666667
# 50%      0.000000    0.000000   66.666667    0.000000   50.000000   90.476190
# 75%    100.000000  100.000000   83.333333    0.000000   84.549689  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#                CO        UNC
# count   91.000000  91.000000
# mean    89.118641  47.666747
# std     18.171175  17.420771
# min      0.000000  15.294117
# 25%     87.500000  35.576923
# 50%    100.000000  45.744680
# 75%    100.000000  56.846152
# max    100.000000  87.999996

# %%
f1['max_value'] = f1.max(axis=1)
f1
# Out:
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\3926272513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['max_value'] = f1.max(axis=1)
#           SemU        SemK       SynU       SynK        SimU        SimK  \
# 0   100.000000  100.000000  97.777778  97.777778  100.000000  100.000000
# 1    41.025641   37.837838  48.484848  52.941176   75.555556   80.952381
# 2    41.025641   37.837838  48.484848  52.941176   75.555556   80.952381
# 3    74.418605   75.000000  81.818182  80.952381   80.000000   75.000000
# 4    68.571429   68.571429  79.069767  80.000000   74.418605   73.684211
# ..         ...         ...        ...        ...         ...         ...
# 86   68.292683   73.684211  82.926829  76.923077   82.926829   73.684211
# 87   71.428571   66.666667  95.238095  90.000000   95.238095   87.179487
# 88   63.414634   66.666667  90.476190  85.000000   90.476190   82.051282
# 89   73.684211   70.270270  95.238095  90.000000   95.238095   87.179487
# 90   97.435897   94.736842  91.891892  88.888889   91.891892   78.787879
#
#           BlU        BlK          CU         DB        JDM          SF  \
# 0   97.777778  97.777778  100.000000   0.000000  56.250000   61.904762
# 1   16.000000  16.000000   52.631579   0.000000  28.571429   36.842105
# 2   16.000000  16.000000   52.631579   0.000000  28.571429   36.842105
# 3    0.000000   0.000000   43.902439   0.000000  16.000000   16.000000
# 4    0.000000   0.000000   40.000000   0.000000  16.000000   16.000000
# ..        ...        ...         ...        ...        ...         ...
# 86   0.000000   0.000000   20.000000   0.000000  12.765957   10.000000
# 87   0.000000   0.000000   71.794872   0.000000  88.888889  100.000000
# 88   0.000000   0.000000   35.897436   0.000000  81.632653   90.909091
# 89   0.000000   0.000000   50.000000   0.000000  39.215686   42.105263
# 90  26.086957  26.086957   89.473684  26.086957  60.000000   86.486486
#
#            CO        UNC   max_value
# 0   64.705882  60.526272  100.000000
# 1   22.222222  52.173867   80.952381
# 2   15.384615  52.173867   80.952381
# 3   45.161290  29.787196   81.818182
# 4   45.161290  32.911350   80.000000
# ..        ...        ...         ...
# 86  35.714286  73.469335   82.926829
# 87  62.500000  51.162738  100.000000
# 88  62.500000  69.767389   90.909091
# 89  53.333333  46.153796   95.238095
# 90  51.851852  63.157842   97.435897
#
# [91 rows x 15 columns]

# %%
f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
#f1['EMBDI_DFT'] = 1- f1['EmbDI']/f1['max_value']
f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
f1
# Out:
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_8632\1342584874.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
#           SemU        SemK       SynU       SynK        SimU        SimK  \
# 0   100.000000  100.000000  97.777778  97.777778  100.000000  100.000000
# 1    41.025641   37.837838  48.484848  52.941176   75.555556   80.952381
# 2    41.025641   37.837838  48.484848  52.941176   75.555556   80.952381
# 3    74.418605   75.000000  81.818182  80.952381   80.000000   75.000000
# 4    68.571429   68.571429  79.069767  80.000000   74.418605   73.684211
# ..         ...         ...        ...        ...         ...         ...
# 86   68.292683   73.684211  82.926829  76.923077   82.926829   73.684211
# 87   71.428571   66.666667  95.238095  90.000000   95.238095   87.179487
# 88   63.414634   66.666667  90.476190  85.000000   90.476190   82.051282
# 89   73.684211   70.270270  95.238095  90.000000   95.238095   87.179487
# 90   97.435897   94.736842  91.891892  88.888889   91.891892   78.787879
#
#           BlU        BlK          CU         DB  ...  SimU_DFT  SimK_DFT  \
# 0   97.777778  97.777778  100.000000   0.000000  ...  0.000000  0.000000
# 1   16.000000  16.000000   52.631579   0.000000  ...  0.066667  0.000000
# 2   16.000000  16.000000   52.631579   0.000000  ...  0.066667  0.000000
# 3    0.000000   0.000000   43.902439   0.000000  ...  0.022222  0.083333
# 4    0.000000   0.000000   40.000000   0.000000  ...  0.069767  0.078947
# ..        ...        ...         ...        ...  ...       ...       ...
# 86   0.000000   0.000000   20.000000   0.000000  ...  0.000000  0.111455
# 87   0.000000   0.000000   71.794872   0.000000  ...  0.047619  0.128205
# 88   0.000000   0.000000   35.897436   0.000000  ...  0.004762  0.097436
# 89   0.000000   0.000000   50.000000   0.000000  ...  0.000000  0.084615
# 90  26.086957  26.086957   89.473684  26.086957  ...  0.056899  0.191388
#
#      BlU_DFT   BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT  \
# 0   0.022222  0.022222  0.000000  0.352941  1.000000  0.437500  0.380952
# 1   0.802353  0.802353  0.349845  0.725490  1.000000  0.647059  0.544892
# 2   0.802353  0.802353  0.349845  0.809955  1.000000  0.647059  0.544892
# 3   1.000000  1.000000  0.463415  0.448029  1.000000  0.804444  0.804444
# 4   1.000000  1.000000  0.500000  0.435484  1.000000  0.800000  0.800000
# ..       ...       ...       ...       ...       ...       ...       ...
# 86  1.000000  1.000000  0.758824  0.569328  1.000000  0.846058  0.879412
# 87  1.000000  1.000000  0.282051  0.375000  1.000000  0.111111  0.000000
# 88  1.000000  1.000000  0.605128  0.312500  1.000000  0.102041  0.000000
# 89  1.000000  1.000000  0.475000  0.440000  1.000000  0.588235  0.557895
# 90  0.732265  0.732265  0.081717  0.467836  0.732265  0.384211  0.112376
#
#      UNC_DFT
# 0   0.394737
# 1   0.355499
# 2   0.355499
# 3   0.635934
# 4   0.588608
# ..       ...
# 86  0.114046
# 87  0.488373
# 88  0.232559
# 89  0.515385
# 90  0.351801
#
# [91 rows x 29 columns]

# %%
dft = f1.filter(regex='DFT').copy()
dft
# Out:
#     SemU_DFT  SemK_DFT  SynU_DFT  SynK_DFT  SimU_DFT  SimK_DFT   BlU_DFT  \
# 0   0.000000  0.000000  0.022222  0.022222  0.000000  0.000000  0.022222
# 1   0.493213  0.532591  0.401070  0.346021  0.066667  0.000000  0.802353
# 2   0.493213  0.532591  0.401070  0.346021  0.066667  0.000000  0.802353
# 3   0.090439  0.083333  0.000000  0.010582  0.022222  0.083333  1.000000
# 4   0.142857  0.142857  0.011628  0.000000  0.069767  0.078947  1.000000
# ..       ...       ...       ...       ...       ...       ...       ...
# 86  0.176471  0.111455  0.000000  0.072398  0.000000  0.111455  1.000000
# 87  0.285714  0.333333  0.047619  0.100000  0.047619  0.128205  1.000000
# 88  0.302439  0.266667  0.004762  0.065000  0.004762  0.097436  1.000000
# 89  0.226316  0.262162  0.000000  0.055000  0.000000  0.084615  1.000000
# 90  0.000000  0.027701  0.056899  0.087719  0.056899  0.191388  0.732265
#
#      BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT   UNC_DFT
# 0   0.022222  0.000000  0.352941  1.000000  0.437500  0.380952  0.394737
# 1   0.802353  0.349845  0.725490  1.000000  0.647059  0.544892  0.355499
# 2   0.802353  0.349845  0.809955  1.000000  0.647059  0.544892  0.355499
# 3   1.000000  0.463415  0.448029  1.000000  0.804444  0.804444  0.635934
# 4   1.000000  0.500000  0.435484  1.000000  0.800000  0.800000  0.588608
# ..       ...       ...       ...       ...       ...       ...       ...
# 86  1.000000  0.758824  0.569328  1.000000  0.846058  0.879412  0.114046
# 87  1.000000  0.282051  0.375000  1.000000  0.111111  0.000000  0.488373
# 88  1.000000  0.605128  0.312500  1.000000  0.102041  0.000000  0.232559
# 89  1.000000  0.475000  0.440000  1.000000  0.588235  0.557895  0.515385
# 90  0.732265  0.081717  0.467836  0.732265  0.384211  0.112376  0.351801
#
# [91 rows x 14 columns]

# %%
dft.describe()
# Out:
#         SemU_DFT   SemK_DFT   SynU_DFT   SynK_DFT   SimU_DFT   SimK_DFT  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean    0.203946   0.236065   0.080026   0.103711   0.037958   0.085533
# std     0.162193   0.178111   0.136828   0.123059   0.049883   0.069402
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.029703   0.029703   0.000000   0.022222   0.000000   0.000000
# 50%     0.226316   0.249412   0.022222   0.056098   0.007442   0.078947
# 75%     0.317073   0.405405   0.084527   0.113520   0.066667   0.128205
# max     0.493213   0.532591   0.502315   0.483173   0.176471   0.239819
#
#          BlU_DFT    BlK_DFT     CU_DFT     CO_DFT     DB_DFT    JDM_DFT  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean    0.813423   0.813423   0.389830   0.497290   0.992099   0.490397
# std     0.327242   0.327242   0.287877   0.177403   0.032902   0.288503
# min     0.000000   0.000000   0.000000   0.189189   0.732265   0.057018
# 25%     0.802353   0.802353   0.141844   0.375000   1.000000   0.184422
# 50%     1.000000   1.000000   0.349845   0.467836   1.000000   0.577475
# 75%     1.000000   1.000000   0.574501   0.606141   1.000000   0.802222
# max     1.000000   1.000000   1.000000   1.000000   1.000000   0.914553
#
#           SF_DFT    UNC_DFT
# count  91.000000  91.000000
# mean    0.358007   0.390725
# std     0.365095   0.142440
# min     0.000000   0.063830
# 25%     0.000000   0.309524
# 50%     0.380952   0.387756
# 75%     0.611111   0.500659
# max     1.000000   0.650407

# %%
dft.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
rt = datasets.filter(regex='runtime').copy()
rt.rename(columns={'UNI: runtime':'SemU', 'K: runtime':'SemK', 'TopKJoin-UNI: runtime':'SynU', 'TopKJoin-K: runtime':'SynK',
                   'EJoin-UNI: runtime':'SimU', 'EJoin-K: runtime':'SimK',                
                   'syntactic-UNI: runtime':'BlU', 'syntactic-K: runtime':'BlK',
                   'CU: runtime':'CU', 'CO: runtime':'CO','DB: runtime':'DB', 'JDM: runtime':'JDM', 
                   'SF: runtime':'SF', 'EmbDI: runtime': 'EmbDI', 'UNICORN: runtime':'UNC'}, inplace=True)
cols = list(rt.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
rt = rt[cols]
rt
# Out:
#          SemU       SemK      SynU      SynK      SimU      SimK  \
# 0    4.920662   5.039338  0.016019  0.104790  0.017314  0.126162
# 1    4.766464   4.855907  0.013132  0.094408  0.014851  0.110853
# 2    4.834251   4.923306  0.012972  0.098061  0.014756  0.110738
# 3   33.917574  37.135876  0.011466  0.088406  0.011763  0.095910
# 4    6.004853   6.084885  0.011322  0.089152  0.010640  0.099176
# ..        ...        ...       ...       ...       ...       ...
# 86  32.056778  32.121152  0.010723  0.081446  0.008963  0.080081
# 87  27.197157  28.038187  0.010893  0.089387  0.009035  0.083660
# 88  28.655153  30.447542  0.009880  0.084888  0.009083  0.086203
# 89  24.717952  24.980411  0.010282  0.080938  0.008792  0.079687
# 90  27.569060  27.555767  0.010848  0.082623  0.010619  0.089583
#
#                    BlU                 BlK         CU        DB       JDM  \
# 0   0.0261911079287529  0.0258170589804649  31.917134  5.362634  4.893861
# 1    0.009344071149826  0.0092729032039642  53.663142  4.492455  4.609198
# 2   0.0097784847021102  0.0096920654177665  31.222057  5.508867  4.745451
# 3                                           20.861633  5.397885  4.753617
# 4                                           21.380411  5.340744  5.011937
# ..                 ...                 ...        ...       ...       ...
# 86                                          38.625944  5.007228  4.712980
# 87                                          23.816698  4.888127  4.466298
# 88                                          32.780709  4.748919  4.271428
# 89                                          34.269884  4.599832  4.248989
# 90  0.0079777762293815   0.007896926254034  35.610923  4.993708  4.519363
#
#           SF        CO       UNC
# 0   4.023147  1.170882  2.476923
# 1   4.538285  0.992834  2.477209
# 2   3.956203  1.003662  2.491792
# 3   2.770762  0.984372  2.476511
# 4   2.782534  1.128458  2.484070
# ..       ...       ...       ...
# 86  2.790416  0.983630  2.355884
# 87  3.398158  1.147720  2.422346
# 88  2.901226  1.050316  2.375348
# 89  2.808231  1.124283  2.425897
# 90  2.566400  1.094151  1.942751
#
# [91 rows x 14 columns]

# %%
ax = sns.boxplot(rt)
ax.set_title("Run-time") 
ax.tick_params(axis='both', labelsize=12)
plt.yscale('log')
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_rt')

# %%
rt.describe()
# Out:
#             SemU       SemK       SynU       SynK       SimU       SimK  \
# count  91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean   32.857586  33.006739   0.020074   0.118018   0.018876   0.128287
# std    19.674669  19.542868   0.012925   0.045042   0.012314   0.052130
# min     4.448394   4.546248   0.009585   0.080576   0.008431   0.079342
# 25%    24.644648  25.142539   0.010785   0.084830   0.009708   0.086534
# 50%    30.533986  30.656720   0.013132   0.093567   0.014590   0.109860
# 75%    47.930779  47.380891   0.027513   0.159774   0.023564   0.177952
# max    77.692433  76.451714   0.081052   0.286661   0.053609   0.264631
#
#                CU         DB        JDM         SF         CO        UNC
# count   91.000000  91.000000  91.000000  91.000000  91.000000  91.000000
# mean   108.980343   5.561722   4.551886  14.381736   1.172850   5.858986
# std    117.561946   0.912023   0.351029  16.156891   0.212322   4.919167
# min     20.628035   4.492455   3.748044   1.062251   0.943425   1.942751
# 25%     27.666501   4.893935   4.349356   2.990821   0.980891   2.425851
# 50%     40.972145   5.209378   4.488797   3.731126   1.101024   2.479448
# 75%    198.597781   6.168808   4.758900  34.752655   1.428995  12.796222
# max    435.725084   7.934434   5.313568  46.321972   1.600241  12.989908
