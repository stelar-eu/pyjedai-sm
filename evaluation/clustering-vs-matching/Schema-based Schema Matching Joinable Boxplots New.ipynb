# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid") 

dataset_type = 'joinable'

main_dir = 'C:/Users/G_A.Papadakis/OneDrive - Public Power Corporation S.A/Schema Matching/Valentine/'
df = pd.read_csv(main_dir + 'results_only_schema_with_re_pr.csv')
df
# Out:
#                         filename   dataset           dataset_type     UNI: F1  \
# 0     assays_horizontal_0_ac1_av    assays              unionable  100.000000
# 1    assays_horizontal_50_ac5_av    assays              unionable   41.025641
# 2    assays_horizontal_50_ac5_ev    assays              unionable   41.025641
# 3     assays_horizontal_0_ac2_ev    assays              unionable   74.418605
# 4    assays_horizontal_50_ac2_av    assays              unionable   68.571429
# ..                           ...       ...                    ...         ...
# 449   prospect_both_50_30_ac2_av  prospect  semantically-joinable   66.666667
# 450  prospect_vertical_30_ac5_av  prospect  semantically-joinable   66.666667
# 451    prospect_both_50_1_ac1_av  prospect  semantically-joinable  100.000000
# 452   prospect_both_50_70_ac3_av  prospect  semantically-joinable   66.666667
# 453        Musicians_semjoinable  Wikidata  semantically-joinable   93.333333
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# 0    100.000000  100.000000      4.920662
# 1     34.782609   50.000000      4.766464
# 2     34.782609   50.000000      4.834251
# 3     69.565217   80.000000     33.917574
# 4     52.173913  100.000000      6.004853
# ..          ...         ...           ...
# 449   50.000000  100.000000     19.324811
# 450   66.666667   66.666667     16.190031
# 451  100.000000  100.000000      3.690933
# 452   66.666667   66.666667     24.956695
# 453   87.500000  100.000000      5.566993
#
#                                            UNI: params       K: F1  \
# 0    {'language_model': 'sdistilroberta', 'similari...  100.000000
# 1    {'language_model': 'sdistilroberta', 'similari...   37.837838
# 2    {'language_model': 'sdistilroberta', 'similari...   37.837838
# 3    {'language_model': 'st5', 'similarity': 0.1, '...   75.000000
# 4    {'language_model': 'sdistilroberta', 'similari...   68.571429
# ..                                                 ...         ...
# 449  {'language_model': 'st5', 'similarity': 0.6, '...   66.666667
# 450  {'language_model': 'st5', 'similarity': 0.5499...   72.727273
# 451  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 452  {'language_model': 'st5', 'similarity': 0.5499...   66.666667
# 453  {'language_model': 'sdistilroberta', 'similari...   93.333333
#
#           K: Re  ...  TopKJoin-K: SUM & AVG   EJoin-K: SUM & AVG  \
# 0    100.000000  ...      66.61141413420947   63.982654399120015
# 1     30.434783  ...     0.1467211765070693  0.14093095682625553
# 2     30.434783  ...
# 3     65.217391  ...
# 4     52.173913  ...
# ..          ...  ...                    ...                  ...
# 449   50.000000  ...
# 450   66.666667  ...
# 451  100.000000  ...
# 452   60.000000  ...
# 453   87.500000  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG        CU: SUM & AVG  \
# 0           379.667373617614        379.667373617614   215.66937309137924
# 1         0.8381178225554392      0.8381178225554392  0.47504267200744327
# 2
# 3
# 4
# ..                       ...                     ...                  ...
# 449
# 450
# 451
# 452
# 453
#
#            CO: SUM & AVG       DB: SUM & AVG      JDM: SUM & AVG  \
# 0     211.83429585498067  451.89064853161904   225.8667252174261
# 1    0.46659536531934065  0.9953538513912313  0.4975038000383835
# 2
# 3
# 4
# ..                   ...                 ...                 ...
# 449
# 450
# 451
# 452
# 453
#
#            SF: SUM & AVG  UNICORN: SUM & AVG
# 0      211.7795502643067  203.94754261040646
# 1    0.46647478031785616  0.4492236621374592
# 2
# 3
# 4
# ..                   ...                 ...
# 449
# 450
# 451
# 452
# 453
#
# [454 rows x 109 columns]

# %%
df[['dataset', 'dataset_type']].value_counts()
# Out:
# dataset   dataset_type
# assays    joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# miller2   joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# prospect  joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# assays    unionable                30
# miller2   unionable                30
# prospect  unionable                30
# Wikidata  joinable                  1
#           semantically-joinable     1
#           unionable                 1
#           view-unionable            1
# dtype: int64

# %%
datasets = df[df['dataset_type'] == dataset_type]
datasets
# Out:
#                         filename   dataset dataset_type     UNI: F1  \
# 91       assays_both_50_1_ac4_ev    assays     joinable   66.666667
# 92      assays_both_50_50_ac2_ev    assays     joinable   80.000000
# 93     assays_vertical_70_ac1_ev    assays     joinable  100.000000
# 94     assays_vertical_70_ac5_ev    assays     joinable   45.161290
# 95     assays_vertical_50_ac2_ev    assays     joinable   73.684211
# ..                           ...       ...          ...         ...
# 207  prospect_vertical_50_ac1_ev  prospect     joinable  100.000000
# 208  prospect_vertical_50_ac5_ev  prospect     joinable   58.823529
# 209   prospect_both_50_70_ac5_ev  prospect     joinable   61.538462
# 210   prospect_vertical_1_ac3_ev  prospect     joinable   50.000000
# 211           Musicians_joinable  Wikidata     joinable   83.333333
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# 91   100.000000   50.000000      8.239186
# 92    72.727273   88.888889     28.563197
# 93   100.000000  100.000000      4.405252
# 94    43.750000   46.666667      4.920819
# 95    63.636364   87.500000     28.541553
# ..          ...         ...           ...
# 207  100.000000  100.000000      4.031143
# 208   45.454545   83.333333     22.958811
# 209   53.333333   72.727273     23.413962
# 210  100.000000   33.333333      4.450178
# 211   83.333333   83.333333     18.711047
#
#                                            UNI: params       K: F1  \
# 91   {'language_model': 'smpnet', 'similarity': 0.1...   66.666667
# 92   {'language_model': 'st5', 'similarity': 0.1, '...   80.000000
# 93   {'language_model': 'sdistilroberta', 'similari...  100.000000
# 94   {'language_model': 'sdistilroberta', 'similari...   44.444444
# 95   {'language_model': 'st5', 'similarity': 0.6, '...   77.777778
# ..                                                 ...         ...
# 207  {'language_model': 'sminilm', 'similarity': 0....  100.000000
# 208  {'language_model': 'st5', 'similarity': 0.1, '...   58.823529
# 209  {'language_model': 'st5', 'similarity': 0.1, '...   66.666667
# 210  {'language_model': 'sdistilroberta', 'similari...   50.000000
# 211  {'language_model': 'st5', 'similarity': 0.65, ...   83.333333
#
#           K: Re  ...  TopKJoin-K: SUM & AVG  EJoin-K: SUM & AVG  \
# 91   100.000000  ...
# 92    72.727273  ...
# 93   100.000000  ...
# 94    37.500000  ...
# 95    63.636364  ...
# ..          ...  ...                    ...                 ...
# 207  100.000000  ...
# 208   45.454545  ...
# 209   53.333333  ...
# 210  100.000000  ...
# 211   83.333333  ...
#
#     syntactic-UNI: SUM & AVG  syntactic-K: SUM & AVG  CU: SUM & AVG  \
# 91
# 92
# 93
# 94
# 95
# ..                       ...                     ...            ...
# 207
# 208
# 209
# 210
# 211
#
#      CO: SUM & AVG DB: SUM & AVG  JDM: SUM & AVG  SF: SUM & AVG  \
# 91
# 92
# 93
# 94
# 95
# ..             ...           ...             ...            ...
# 207
# 208
# 209
# 210
# 211
#
#      UNICORN: SUM & AVG
# 91
# 92
# 93
# 94
# 95
# ..                  ...
# 207
# 208
# 209
# 210
# 211
#
# [121 rows x 109 columns]

# %%
f1 = datasets.filter(regex='F1').copy()
f1 = f1.astype('float64')
f1
# Out:
#         UNI: F1       K: F1  TopKJoin-UNI: F1  EJoin-UNI: F1  TopKJoin-K: F1  \
# 91    66.666667   66.666667         40.000000      40.000000       40.000000
# 92    80.000000   80.000000         76.190476      72.727273       76.190476
# 93   100.000000  100.000000         96.774194      96.774194       96.969697
# 94    45.161290   44.444444         59.259259      78.787879       50.000000
# 95    73.684211   77.777778         86.956522      86.956522       90.909091
# ..          ...         ...               ...            ...             ...
# 207  100.000000  100.000000        100.000000     100.000000      100.000000
# 208   58.823529   58.823529         85.714286      85.714286       80.000000
# 209   61.538462   66.666667         82.758621      82.758621       82.758621
# 210   50.000000   50.000000          0.000000       0.000000        0.000000
# 211   83.333333   83.333333         85.714286      80.000000       85.714286
#
#      EJoin-K: F1  syntactic-UNI: F1  syntactic-K: F1      CU: F1     DB: F1  \
# 91      0.000000           0.000000         0.000000    0.000000   0.000000
# 92     70.000000           0.000000         0.000000   13.333333   0.000000
# 93     96.969697          96.774194        96.774194   88.235294   0.000000
# 94     80.000000          22.222222        22.222222   53.333333   0.000000
# 95     90.909091           0.000000         0.000000   36.363636   0.000000
# ..           ...                ...              ...         ...        ...
# 207   100.000000         100.000000       100.000000  100.000000   0.000000
# 208    80.000000           0.000000         0.000000   40.000000   0.000000
# 209    78.571429           0.000000         0.000000   46.153846   0.000000
# 210     0.000000           0.000000         0.000000   66.666667   0.000000
# 211    85.714286          28.571429        28.571429   50.000000  28.571429
#
#         JDM: F1     SF: F1     CO: F1  UNICORN: F1      max F1
# 91    22.222222  15.384615   0.000000     8.333325   66.666667
# 92    28.571429  78.571429  58.823529    32.142824   80.000000
# 93    45.833333  91.428571  60.869565    58.181775  100.000000
# 94    27.586207  46.666667  21.052632    54.166620   80.000000
# 95    16.666667  15.384615  50.000000    31.111073   90.909091
# ..          ...        ...        ...          ...         ...
# 207   80.000000  91.666667  90.000000    91.666609  100.000000
# 208   40.000000  34.782609  53.333333    48.275812   85.714286
# 209   37.837838  53.333333  57.142857    45.714234   82.758621
# 210  100.000000  22.222222   0.000000    66.666578  100.000000
# 211   72.727273  70.588235  72.727273    72.727210   85.714286
#
# [121 rows x 15 columns]

# %%
f1.drop(columns=['max F1'], inplace=True)
f1.rename(columns={'UNI: F1':'SemU', 'K: F1':'SemK', 'TopKJoin-UNI: F1':'SynU', 'TopKJoin-K: F1':'SynK',
                   'EJoin-UNI: F1':'SimU', 'EJoin-K: F1':'SimK',                
                   'syntactic-UNI: F1':'BlU', 'syntactic-K: F1':'BlK',
                   'CU: F1':'CU', 'CO: F1':'CO','DB: F1':'DB', 'JDM: F1':'JDM', 
                   'SF: F1':'SF', 'EmbDI: F1': 'EmbDI', 'UNICORN: F1':'UNC'}, inplace=True)
cols = list(f1.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
f1 = f1[cols]
f1
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 91    66.666667   66.666667   40.000000   40.000000   40.000000    0.000000
# 92    80.000000   80.000000   76.190476   76.190476   72.727273   70.000000
# 93   100.000000  100.000000   96.774194   96.969697   96.774194   96.969697
# 94    45.161290   44.444444   59.259259   50.000000   78.787879   80.000000
# 95    73.684211   77.777778   86.956522   90.909091   86.956522   90.909091
# ..          ...         ...         ...         ...         ...         ...
# 207  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 208   58.823529   58.823529   85.714286   80.000000   85.714286   80.000000
# 209   61.538462   66.666667   82.758621   82.758621   82.758621   78.571429
# 210   50.000000   50.000000    0.000000    0.000000    0.000000    0.000000
# 211   83.333333   83.333333   85.714286   85.714286   80.000000   85.714286
#
#             BlU         BlK          CU         DB         JDM         SF  \
# 91     0.000000    0.000000    0.000000   0.000000   22.222222  15.384615
# 92     0.000000    0.000000   13.333333   0.000000   28.571429  78.571429
# 93    96.774194   96.774194   88.235294   0.000000   45.833333  91.428571
# 94    22.222222   22.222222   53.333333   0.000000   27.586207  46.666667
# 95     0.000000    0.000000   36.363636   0.000000   16.666667  15.384615
# ..          ...         ...         ...        ...         ...        ...
# 207  100.000000  100.000000  100.000000   0.000000   80.000000  91.666667
# 208    0.000000    0.000000   40.000000   0.000000   40.000000  34.782609
# 209    0.000000    0.000000   46.153846   0.000000   37.837838  53.333333
# 210    0.000000    0.000000   66.666667   0.000000  100.000000  22.222222
# 211   28.571429   28.571429   50.000000  28.571429   72.727273  70.588235
#
#             CO        UNC
# 91    0.000000   8.333325
# 92   58.823529  32.142824
# 93   60.869565  58.181775
# 94   21.052632  54.166620
# 95   50.000000  31.111073
# ..         ...        ...
# 207  90.000000  91.666609
# 208  53.333333  48.275812
# 209  57.142857  45.714234
# 210   0.000000  66.666578
# 211  72.727273  72.727210
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(f1)
ax.set_title("F-Measure") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_f1')

# %%
f1.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    67.668409   67.513550   71.028958   71.077900   70.044868   70.034015
# std     25.726174   25.727303   28.334832   27.989184   28.572246   29.281517
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     50.000000   50.000000   59.259259   60.000000   57.627119   63.636364
# 50%     66.666667   66.666667   78.260870   77.419355   76.923077   76.923077
# 75%     98.039216   98.039216   93.750000   92.307692   93.750000   92.307692
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    15.099405   15.099405   42.440535    0.282041   44.030604   44.304503
# std     31.161963   31.161963   28.209625    2.641915   33.756333   34.419871
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   22.222222    0.000000   11.764706   12.500000
# 50%      0.000000    0.000000   41.176471    0.000000   35.294118   34.782609
# 75%     10.810811   10.810811   61.538462    0.000000   80.000000   78.571429
# max    100.000000  100.000000  100.000000   28.571429  100.000000  100.000000
#
#                CO         UNC
# count  121.000000  121.000000
# mean    46.823314   45.778100
# std     26.935088   25.146573
# min      0.000000    0.000000
# 25%     31.250000   28.571396
# 50%     50.000000   48.275812
# 75%     70.370370   58.823477
# max    100.000000   99.999933

# %%
re = datasets.filter(regex='Re').copy()
re.rename(columns={'UNI: Re':'SemU', 'K: Re':'SemK', 'TopKJoin-UNI: Re':'SynU', 'TopKJoin-K: Re':'SynK',
                   'EJoin-UNI: Re':'SimU', 'EJoin-K: Re':'SimK',                
                   'syntactic-UNI: Re':'BlU', 'syntactic-K: Re':'BlK',
                   'CU: Re':'CU', 'CO: Re':'CO','DB: Re':'DB', 'JDM: Re':'JDM', 
                   'SF: Re':'SF', 'EmbDI: Re': 'EmbDI', 'UNICORN: Re':'UNC'}, inplace=True)
cols = list(re.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
re = re[cols]
re
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 91   100.000000  100.000000  100.000000  100.000000  100.000000    0.000000
# 92    72.727273   72.727273   72.727273   72.727273   72.727273   63.636364
# 93   100.000000  100.000000   93.750000  100.000000   93.750000  100.000000
# 94    43.750000   37.500000   50.000000   37.500000   81.250000   75.000000
# 95    63.636364   63.636364   90.909091   90.909091   90.909091   90.909091
# ..          ...         ...         ...         ...         ...         ...
# 207  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 208   45.454545   45.454545   81.818182   72.727273   81.818182   72.727273
# 209   53.333333   53.333333   80.000000   80.000000   80.000000   73.333333
# 210  100.000000  100.000000    0.000000    0.000000    0.000000    0.000000
# 211   83.333333   83.333333  100.000000  100.000000  100.000000  100.000000
#
#             BlU         BlK          CU         DB         JDM          SF  \
# 91     0.000000    0.000000    0.000000   0.000000  100.000000  100.000000
# 92     0.000000    0.000000    9.090909   0.000000   18.181818  100.000000
# 93    93.750000   93.750000   93.750000   0.000000   68.750000  100.000000
# 94    12.500000   12.500000   50.000000   0.000000   25.000000   43.750000
# 95     0.000000    0.000000   36.363636   0.000000    9.090909    9.090909
# ..          ...         ...         ...        ...         ...         ...
# 207  100.000000  100.000000  100.000000   0.000000   72.727273  100.000000
# 208    0.000000    0.000000   36.363636   0.000000   45.454545   36.363636
# 209    0.000000    0.000000   40.000000   0.000000   46.666667   53.333333
# 210    0.000000    0.000000  100.000000   0.000000  100.000000  100.000000
# 211   16.666667   16.666667   50.000000  16.666667   66.666667  100.000000
#
#             CO        UNC
# 91    0.000000  99.999900
# 92   45.454545  81.818174
# 93   43.750000  99.999994
# 94   12.500000  81.249995
# 95   36.363636  63.636358
# ..         ...        ...
# 207  81.818182  99.999991
# 208  36.363636  63.636358
# 209  40.000000  53.333330
# 210   0.000000  99.999900
# 211  66.666667  66.666656
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(re)
ax.set_title("Recall") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_re')

# %%
re.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    71.911166   70.340703   77.744553   76.158921   78.572028   74.469608
# std     26.998496   27.674256   27.110964   27.071942   26.363534   28.226765
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     52.000000   50.000000   66.666667   65.714286   66.666667   66.666667
# 50%     72.727273   71.428571   85.714286   80.000000   84.000000   80.000000
# 75%    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    13.308764   13.308764   51.836169    0.161354   62.505554   74.190449
# std     30.417642   30.417642   34.598032    1.535119   34.181280   36.234935
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   27.272727    0.000000   33.333333   43.750000
# 50%      0.000000    0.000000   48.571429    0.000000   68.000000  100.000000
# 75%      5.714286    5.714286   83.333333    0.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000   16.666667  100.000000  100.000000
#
#                CO         UNC
# count  121.000000  121.000000
# mean    45.722854   71.849643
# std     32.157672   29.184448
# min      0.000000    0.000000
# 25%     20.000000   55.999998
# 50%     40.000000   77.142855
# 75%     66.666667   99.999900
# max    100.000000   99.999997

# %%
pr = datasets.filter(regex='Pr').copy()
pr.rename(columns={'UNI: Pr':'SemU', 'K: Pr':'SemK', 'TopKJoin-UNI: Pr':'SynU', 'TopKJoin-K: Pr':'SynK',
                   'EJoin-UNI: Pr':'SimU', 'EJoin-K: Pr':'SimK',                
                   'syntactic-UNI: Pr':'BlU', 'syntactic-K: Pr':'BlK',
                   'CU: Pr':'CU', 'CO: Pr':'CO','DB: Pr':'DB', 'JDM: Pr':'JDM', 
                   'SF: Pr':'SF', 'EmbDI: Pr': 'EmbDI', 'UNICORN: Pr':'UNC'}, inplace=True)
cols = list(pr.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
pr = pr[cols]
pr
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 91    50.000000   50.000000   25.000000   25.000000   25.000000    0.000000
# 92    88.888889   88.888889   80.000000   80.000000   72.727273   77.777778
# 93   100.000000  100.000000  100.000000   94.117647  100.000000   94.117647
# 94    46.666667   54.545455   72.727273   75.000000   76.470588   85.714286
# 95    87.500000  100.000000   83.333333   90.909091   83.333333   90.909091
# ..          ...         ...         ...         ...         ...         ...
# 207  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 208   83.333333   83.333333   90.000000   88.888889   90.000000   88.888889
# 209   72.727273   88.888889   85.714286   85.714286   85.714286   84.615385
# 210   33.333333   33.333333    0.000000    0.000000    0.000000    0.000000
# 211   83.333333   83.333333   75.000000   75.000000   66.666667   75.000000
#
#        BlU    BlK          CU     DB         JDM         SF          CO  \
# 91     0.0    0.0    0.000000    0.0   12.500000   8.333333    0.000000
# 92     0.0    0.0   25.000000    0.0   66.666667  64.705882   83.333333
# 93   100.0  100.0   83.333333    0.0   34.375000  84.210526  100.000000
# 94   100.0  100.0   57.142857    0.0   30.769231  50.000000   66.666667
# 95     0.0    0.0   36.363636    0.0  100.000000  50.000000   80.000000
# ..     ...    ...         ...    ...         ...        ...         ...
# 207  100.0  100.0  100.000000    0.0   88.888889  84.615385  100.000000
# 208    0.0    0.0   44.444444    0.0   35.714286  33.333333  100.000000
# 209    0.0    0.0   54.545455    0.0   31.818182  53.333333  100.000000
# 210    0.0    0.0   50.000000    0.0  100.000000  12.500000    0.000000
# 211  100.0  100.0   50.000000  100.0   80.000000  54.545455   80.000000
#
#            UNC
# 91    4.347826
# 92   20.000000
# 93   41.025640
# 94   40.624999
# 95   20.588235
# ..         ...
# 207  84.615378
# 208  38.888887
# 209  39.999998
# 210  49.999975
# 211  79.999984
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(pr)
ax.set_title("Precision") 
ax.tick_params(axis='both', labelsize=12)
plt.xticks(rotation=45)
plt.ylim(-1, 101)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_pr')

# %%
pr.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    69.014654   70.752023   70.866634   72.955489   68.906008   71.267221
# std     27.175646   27.086873   30.098423   30.220560   30.597959   31.419756
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     50.000000   55.000000   60.000000   62.500000   55.555556   62.500000
# 50%     71.428571   75.000000   80.000000   84.848485   76.470588   83.333333
# 75%     97.222222  100.000000   92.592593   93.750000   92.857143   93.333333
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CU          DB         JDM          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    29.539194   29.539194   39.823830    1.652893   45.613637   40.330648
# std     45.609636   45.609636   27.420686   12.802806   36.939722   33.540889
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   20.000000    0.000000   10.000000    8.333333
# 50%      0.000000    0.000000   40.000000    0.000000   33.333333   40.000000
# 75%    100.000000  100.000000   57.142857    0.000000   83.333333   71.428571
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#                CO         UNC
# count  121.000000  121.000000
# mean    65.228853   38.135425
# std     36.800583   25.927245
# min      0.000000    0.000000
# 25%     33.333333   18.644067
# 50%     80.000000   36.507936
# 75%    100.000000   49.999997
# max    100.000000   99.999983

# %%
f1['max_value'] = f1.max(axis=1)
f1
# Out:
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\3926272513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['max_value'] = f1.max(axis=1)
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 91    66.666667   66.666667   40.000000   40.000000   40.000000    0.000000
# 92    80.000000   80.000000   76.190476   76.190476   72.727273   70.000000
# 93   100.000000  100.000000   96.774194   96.969697   96.774194   96.969697
# 94    45.161290   44.444444   59.259259   50.000000   78.787879   80.000000
# 95    73.684211   77.777778   86.956522   90.909091   86.956522   90.909091
# ..          ...         ...         ...         ...         ...         ...
# 207  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 208   58.823529   58.823529   85.714286   80.000000   85.714286   80.000000
# 209   61.538462   66.666667   82.758621   82.758621   82.758621   78.571429
# 210   50.000000   50.000000    0.000000    0.000000    0.000000    0.000000
# 211   83.333333   83.333333   85.714286   85.714286   80.000000   85.714286
#
#             BlU         BlK          CU         DB         JDM         SF  \
# 91     0.000000    0.000000    0.000000   0.000000   22.222222  15.384615
# 92     0.000000    0.000000   13.333333   0.000000   28.571429  78.571429
# 93    96.774194   96.774194   88.235294   0.000000   45.833333  91.428571
# 94    22.222222   22.222222   53.333333   0.000000   27.586207  46.666667
# 95     0.000000    0.000000   36.363636   0.000000   16.666667  15.384615
# ..          ...         ...         ...        ...         ...        ...
# 207  100.000000  100.000000  100.000000   0.000000   80.000000  91.666667
# 208    0.000000    0.000000   40.000000   0.000000   40.000000  34.782609
# 209    0.000000    0.000000   46.153846   0.000000   37.837838  53.333333
# 210    0.000000    0.000000   66.666667   0.000000  100.000000  22.222222
# 211   28.571429   28.571429   50.000000  28.571429   72.727273  70.588235
#
#             CO        UNC   max_value
# 91    0.000000   8.333325   66.666667
# 92   58.823529  32.142824   80.000000
# 93   60.869565  58.181775  100.000000
# 94   21.052632  54.166620   80.000000
# 95   50.000000  31.111073   90.909091
# ..         ...        ...         ...
# 207  90.000000  91.666609  100.000000
# 208  53.333333  48.275812   85.714286
# 209  57.142857  45.714234   82.758621
# 210   0.000000  66.666578  100.000000
# 211  72.727273  72.727210   85.714286
#
# [121 rows x 15 columns]

# %%
f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
#f1['EMBDI_DFT'] = 1- f1['EmbDI']/f1['max_value']
f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
f1
# Out:
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
# C:\Users\G_A.Papadakis\AppData\Local\Temp\ipykernel_17828\1342584874.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 91    66.666667   66.666667   40.000000   40.000000   40.000000    0.000000
# 92    80.000000   80.000000   76.190476   76.190476   72.727273   70.000000
# 93   100.000000  100.000000   96.774194   96.969697   96.774194   96.969697
# 94    45.161290   44.444444   59.259259   50.000000   78.787879   80.000000
# 95    73.684211   77.777778   86.956522   90.909091   86.956522   90.909091
# ..          ...         ...         ...         ...         ...         ...
# 207  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 208   58.823529   58.823529   85.714286   80.000000   85.714286   80.000000
# 209   61.538462   66.666667   82.758621   82.758621   82.758621   78.571429
# 210   50.000000   50.000000    0.000000    0.000000    0.000000    0.000000
# 211   83.333333   83.333333   85.714286   85.714286   80.000000   85.714286
#
#             BlU         BlK          CU         DB  ...  SimU_DFT  SimK_DFT  \
# 91     0.000000    0.000000    0.000000   0.000000  ...  0.400000  1.000000
# 92     0.000000    0.000000   13.333333   0.000000  ...  0.090909  0.125000
# 93    96.774194   96.774194   88.235294   0.000000  ...  0.032258  0.030303
# 94    22.222222   22.222222   53.333333   0.000000  ...  0.015152  0.000000
# 95     0.000000    0.000000   36.363636   0.000000  ...  0.043478  0.000000
# ..          ...         ...         ...        ...  ...       ...       ...
# 207  100.000000  100.000000  100.000000   0.000000  ...  0.000000  0.000000
# 208    0.000000    0.000000   40.000000   0.000000  ...  0.000000  0.066667
# 209    0.000000    0.000000   46.153846   0.000000  ...  0.000000  0.050595
# 210    0.000000    0.000000   66.666667   0.000000  ...  1.000000  1.000000
# 211   28.571429   28.571429   50.000000  28.571429  ...  0.066667  0.000000
#
#       BlU_DFT   BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT  \
# 91   1.000000  1.000000  1.000000  1.000000  1.000000  0.666667  0.769231
# 92   1.000000  1.000000  0.833333  0.264706  1.000000  0.642857  0.017857
# 93   0.032258  0.032258  0.117647  0.391304  1.000000  0.541667  0.085714
# 94   0.722222  0.722222  0.333333  0.736842  1.000000  0.655172  0.416667
# 95   1.000000  1.000000  0.600000  0.450000  1.000000  0.816667  0.830769
# ..        ...       ...       ...       ...       ...       ...       ...
# 207  0.000000  0.000000  0.000000  0.100000  1.000000  0.200000  0.083333
# 208  1.000000  1.000000  0.533333  0.377778  1.000000  0.533333  0.594203
# 209  1.000000  1.000000  0.442308  0.309524  1.000000  0.542793  0.355556
# 210  1.000000  1.000000  0.333333  1.000000  1.000000  0.000000  0.777778
# 211  0.666667  0.666667  0.416667  0.151515  0.666667  0.151515  0.176471
#
#       UNC_DFT
# 91   0.875000
# 92   0.598215
# 93   0.418182
# 94   0.322917
# 95   0.657778
# ..        ...
# 207  0.083334
# 208  0.436782
# 209  0.447620
# 210  0.333334
# 211  0.151516
#
# [121 rows x 29 columns]

# %%
dft = f1.filter(regex='DFT').copy()
dft
# Out:
#      SemU_DFT  SemK_DFT  SynU_DFT  SynK_DFT  SimU_DFT  SimK_DFT   BlU_DFT  \
# 91   0.000000  0.000000  0.400000  0.400000  0.400000  1.000000  1.000000
# 92   0.000000  0.000000  0.047619  0.047619  0.090909  0.125000  1.000000
# 93   0.000000  0.000000  0.032258  0.030303  0.032258  0.030303  0.032258
# 94   0.435484  0.444444  0.259259  0.375000  0.015152  0.000000  0.722222
# 95   0.189474  0.144444  0.043478  0.000000  0.043478  0.000000  1.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 207  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 208  0.313725  0.313725  0.000000  0.066667  0.000000  0.066667  1.000000
# 209  0.256410  0.194444  0.000000  0.000000  0.000000  0.050595  1.000000
# 210  0.500000  0.500000  1.000000  1.000000  1.000000  1.000000  1.000000
# 211  0.027778  0.027778  0.000000  0.000000  0.066667  0.000000  0.666667
#
#       BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT   UNC_DFT
# 91   1.000000  1.000000  1.000000  1.000000  0.666667  0.769231  0.875000
# 92   1.000000  0.833333  0.264706  1.000000  0.642857  0.017857  0.598215
# 93   0.032258  0.117647  0.391304  1.000000  0.541667  0.085714  0.418182
# 94   0.722222  0.333333  0.736842  1.000000  0.655172  0.416667  0.322917
# 95   1.000000  0.600000  0.450000  1.000000  0.816667  0.830769  0.657778
# ..        ...       ...       ...       ...       ...       ...       ...
# 207  0.000000  0.000000  0.100000  1.000000  0.200000  0.083333  0.083334
# 208  1.000000  0.533333  0.377778  1.000000  0.533333  0.594203  0.436782
# 209  1.000000  0.442308  0.309524  1.000000  0.542793  0.355556  0.447620
# 210  1.000000  0.333333  1.000000  1.000000  0.000000  0.777778  0.333334
# 211  0.666667  0.416667  0.151515  0.666667  0.151515  0.176471  0.151516
#
# [121 rows x 14 columns]

# %%
dft.describe()
# Out:
#          SemU_DFT    SemK_DFT    SynU_DFT    SynK_DFT    SimU_DFT    SimK_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.195984    0.196702    0.162812    0.160269    0.179086    0.171290
# std      0.228343    0.230549    0.258166    0.257505    0.259997    0.279359
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.133333    0.142857    0.047619    0.043678    0.086957    0.055556
# 75%      0.331818    0.314000    0.212121    0.212121    0.212121    0.216862
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           BlU_DFT     BlK_DFT      CU_DFT      CO_DFT      DB_DFT     JDM_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.842466    0.842466    0.502168    0.457953    0.996743    0.493998
# std      0.315096    0.315096    0.299259    0.296298    0.030757    0.347579
# min      0.000000    0.000000    0.000000    0.000000    0.666667    0.000000
# 25%      0.881757    0.881757    0.285714    0.222222    1.000000    0.133333
# 50%      1.000000    1.000000    0.477812    0.423529    1.000000    0.541667
# 75%      1.000000    1.000000    0.695238    0.635628    1.000000    0.838726
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            SF_DFT     UNC_DFT
# count  121.000000  121.000000
# mean     0.482413    0.463347
# std      0.355493    0.251693
# min      0.000000    0.000000
# 25%      0.119981    0.313726
# 50%      0.498182    0.436782
# 75%      0.819444    0.571429
# max      1.000000    1.000000

# %%
dft.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
rt = datasets.filter(regex='runtime').copy()
rt.rename(columns={'UNI: runtime':'SemU', 'K: runtime':'SemK', 'TopKJoin-UNI: runtime':'SynU', 'TopKJoin-K: runtime':'SynK',
                   'EJoin-UNI: runtime':'SimU', 'EJoin-K: runtime':'SimK',                
                   'syntactic-UNI: runtime':'BlU', 'syntactic-K: runtime':'BlK',
                   'CU: runtime':'CU', 'CO: runtime':'CO','DB: runtime':'DB', 'JDM: runtime':'JDM', 
                   'SF: runtime':'SF', 'EmbDI: runtime': 'EmbDI', 'UNICORN: runtime':'UNC'}, inplace=True)
cols = list(rt.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
rt = rt[cols]
rt
# Out:
#           SemU       SemK      SynU      SynK      SimU      SimK  \
# 91    8.239186   8.287461  0.006487  0.039438  0.006068  0.050840
# 92   28.563197  28.638168  0.007523  0.059253  0.007128  0.064059
# 93    4.405252   4.505070  0.012725  0.090175  0.010764  0.100779
# 94    4.920819   5.003557  0.011784  0.079081  0.011298  0.087058
# 95   28.541553  26.180403  0.008033  0.060605  0.007240  0.063372
# ..         ...        ...       ...       ...       ...       ...
# 207   4.031143   4.114731  0.008383  0.062724  0.006837  0.062717
# 208  22.958811  23.041053  0.007122  0.057399  0.006439  0.056190
# 209  23.413962  22.826576  0.008515  0.066002  0.007290  0.065023
# 210   4.450178   4.504928  0.005083  0.035962  0.004388  0.035065
# 211  18.711047   4.526900  0.006410  0.049991  0.005924  0.051557
#
#                     BlU                 BlK         CU        DB       JDM  \
# 91                                           24.246118  4.882396  5.208077
# 92                                           26.088284  4.591416  5.049292
# 93   0.0193936377763748  0.0192179232835769  49.413044  5.809656  4.315067
# 94   0.0087889917194843  0.0087285824120044  43.110308  5.181720  4.210259
# 95                                           24.310042  4.876496  4.217607
# ..                  ...                 ...        ...       ...       ...
# 207  0.0132495164871215  0.0131949558854103  34.314472  4.334001  4.461494
# 208                                          28.259096  4.545158  4.452683
# 209                                          30.286104  4.384910  4.334755
# 210                                          18.932751  4.407069  4.360246
# 211   0.006411537528038  0.0063370466232299  24.873798  4.505383  4.249139
#
#            SF        CO       UNC
# 91   0.647841  0.983269  0.674240
# 92   0.992657  0.976292  1.355411
# 93   1.672122  1.164741  1.757082
# 94   0.603188  1.001432  1.771066
# 95   2.380684  0.937402  1.347231
# ..        ...       ...       ...
# 207  1.619355  1.024678  1.309502
# 208  1.279164  0.941729  1.305626
# 209  1.823039  0.981337  1.646158
# 210  0.394426  1.019005  0.635632
# 211  0.760389  0.926458  0.844369
#
# [121 rows x 14 columns]

# %%
ax = sns.boxplot(rt)
ax.set_title("Run-time") 
ax.tick_params(axis='both', labelsize=12)
plt.yscale('log')
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_rt')

# %%
rt.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    19.748824   19.781560    0.011319    0.066780    0.010293    0.073409
# std     15.301343   15.368978    0.006524    0.027228    0.009458    0.036380
# min      2.898365    2.951140    0.004599    0.035485    0.004127    0.034541
# 25%      4.527209    4.673638    0.006742    0.046989    0.005694    0.048574
# 50%     20.632806   20.512675    0.008702    0.059803    0.007476    0.064058
# 75%     29.273557   29.686892    0.013597    0.076297    0.010949    0.083210
# max     62.118894   61.848034    0.031135    0.148261    0.095354    0.237222
#
#                CU          DB         JDM          SF          CO         UNC
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    54.457488    4.938524    4.445047    4.801703    1.065280    2.788739
# std     46.300788    0.445739    0.253947    6.379436    0.155603    2.643879
# min     18.932751    3.908766    3.557771    0.176328    0.878903    0.635632
# 25%     24.822346    4.582708    4.324449    0.882758    0.945625    0.974686
# 50%     32.246459    4.876496    4.418610    1.731560    1.012412    1.360645
# 75%     64.012306    5.260428    4.537762    4.953025    1.155455    3.289430
# max    206.551198    6.178213    5.421873   23.853430    1.466111    9.025634
