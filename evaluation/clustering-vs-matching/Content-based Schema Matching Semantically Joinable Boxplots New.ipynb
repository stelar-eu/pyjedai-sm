# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid") 

dataset_type = 'semantically-joinable'

main_dir = 'C:/Users/G_A.Papadakis/OneDrive - Public Power Corporation S.A/Schema Matching/Valentine/'
df = pd.read_csv(main_dir + 'results_only_data_with_re_pr.csv')
df
# Out:
#                          filename   dataset           dataset_type  \
# 0     assays_horizontal_50_ac4_ev    assays              unionable
# 1     assays_horizontal_50_ac2_av    assays              unionable
# 2      assays_horizontal_0_ac4_ev    assays              unionable
# 3      assays_horizontal_0_ac5_ev    assays              unionable
# 4    assays_horizontal_100_ac3_ev    assays              unionable
# ..                            ...       ...                    ...
# 449    prospect_vertical_1_ac3_av  prospect  semantically-joinable
# 450    prospect_both_50_50_ac5_av  prospect  semantically-joinable
# 451    prospect_vertical_1_ac5_av  prospect  semantically-joinable
# 452    prospect_both_50_30_ac1_av  prospect  semantically-joinable
# 453         Musicians_semjoinable  Wikidata  semantically-joinable
#
#         UNI: F1     UNI: Re     UNI: Pr  UNI: runtime  \
# 0     88.888889   86.956522   90.909091      9.836186
# ...

# %%
df[['dataset', 'dataset_type']].value_counts()
# Out:
# dataset   dataset_type
# assays    joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# miller2   joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# prospect  joinable                 40
#           semantically-joinable    40
#           view-unionable           40
# assays    unionable                30
# miller2   unionable                30
# prospect  unionable                30
# Wikidata  joinable                  1
#           semantically-joinable     1
#           unionable                 1
#           view-unionable            1
# dtype: int64

# %%
datasets = df[df['dataset_type'] == dataset_type]
datasets
# Out:
#                        filename   dataset           dataset_type     UNI: F1  \
# 333    assays_both_50_70_ac3_av    assays  semantically-joinable   73.333333
# 334    assays_both_50_50_ac5_av    assays  semantically-joinable   66.666667
# 335    assays_both_50_50_ac1_av    assays  semantically-joinable   70.000000
# 336    assays_both_50_50_ac3_av    assays  semantically-joinable   76.190476
# 337    assays_vertical_1_ac3_av    assays  semantically-joinable   40.000000
# ..                          ...       ...                    ...         ...
# 449  prospect_vertical_1_ac3_av  prospect  semantically-joinable  100.000000
# 450  prospect_both_50_50_ac5_av  prospect  semantically-joinable   72.727273
# 451  prospect_vertical_1_ac5_av  prospect  semantically-joinable  100.000000
# 452  prospect_both_50_30_ac1_av  prospect  semantically-joinable   90.909091
# 453       Musicians_semjoinable  Wikidata  semantically-joinable   82.352941
#
#         UNI: Re     UNI: Pr  UNI: runtime  \
# ...

# %%
f1 = datasets.filter(regex='F1').copy()
f1
# Out:
#         UNI: F1       K: F1  TopKJoin-UNI: F1  EJoin-UNI: F1  TopKJoin-K: F1  \
# 333   73.333333   80.000000         50.000000      50.000000       56.000000
# 334   66.666667   83.333333         43.478261      43.478261       63.157895
# 335   70.000000   80.000000         70.588235      58.823529       70.588235
# 336   76.190476   85.714286         69.565217      69.565217       66.666667
# 337   40.000000   50.000000         50.000000      50.000000       50.000000
# ..          ...         ...               ...            ...             ...
# 449  100.000000  100.000000         66.666667      66.666667       66.666667
# 450   72.727273   72.727273         50.000000      40.000000       57.142857
# 451  100.000000  100.000000         66.666667      66.666667       66.666667
# 452   90.909091   90.909091         57.142857      57.142857       50.000000
# 453   82.352941   87.500000         88.888889      87.500000       88.888889
#
# ...

# %%
f1 = datasets.filter(regex='F1').copy()
f1.drop(columns=['max F1'], inplace=True)
f1.rename(columns={'UNI: F1':'SemU', 'K: F1':'SemK', 'TopKJoin-UNI: F1':'SynU', 'TopKJoin-K: F1':'SynK',
                   'EJoin-UNI: F1':'SimU', 'EJoin-K: F1':'SimK',                
                   'syntactic-UNI: F1':'BlU', 'syntactic-K: F1':'BlK',
                   'CU: F1':'CU', 'CO: F1':'CO','DB: F1':'DB', 'JDM: F1':'JDM', 
                   'SF: F1':'SF', 'EmbDI: F1': 'EmbDI', 'UNICORN: F1':'UNC'}, inplace=True)
cols = list(f1.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
f1 = f1[cols]
f1
# Out:
#            SemU        SemK       SynU       SynK       SimU       SimK  \
# 333   73.333333   80.000000  50.000000  56.000000  50.000000  54.545455
# 334   66.666667   83.333333  43.478261  63.157895  43.478261  63.157895
# 335   70.000000   80.000000  70.588235  70.588235  58.823529  62.500000
# 336   76.190476   85.714286  69.565217  66.666667  69.565217  66.666667
# 337   40.000000   50.000000  50.000000  50.000000  50.000000  50.000000
# ..          ...         ...        ...        ...        ...        ...
# 449  100.000000  100.000000  66.666667  66.666667  66.666667  66.666667
# 450   72.727273   72.727273  50.000000  57.142857  40.000000  40.000000
# 451  100.000000  100.000000  66.666667  66.666667  66.666667  66.666667
# 452   90.909091   90.909091  57.142857  50.000000  57.142857  50.000000
# 453   82.352941   87.500000  88.888889  88.888889  87.500000  87.500000
#
#            BlU        BlK         CO         CU          DB         SF  \
# ...

# %%
ax = sns.boxplot(f1)
ax.set_title("F-Measure") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_f1')

# %%
f1.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    65.665851   68.882090   51.353717   53.357254   49.374228   50.231548
# std     22.826779   22.427494   22.280906   22.363478   21.611207   22.916067
# min     16.666667   16.666667    0.000000    0.000000    0.000000    0.000000
# 25%     50.980392   53.968254   44.444444   44.444444   43.750000   38.461538
# 50%     67.924528   72.727273   58.461538   53.846154   55.737705   50.000000
# 75%     82.758621   85.714286   66.666667   66.666667   63.157895   66.666667
# max    100.000000  100.000000   88.888889  100.000000   87.500000  100.000000
#
#               BlU         BlK          CO          CU          DB          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    56.688791   49.930657    4.014331   15.925158   44.104217   26.283126
# ...

# %%
re = datasets.filter(regex='Re').copy()
re.rename(columns={'UNI: Re':'SemU', 'K: Re':'SemK', 'TopKJoin-UNI: Re':'SynU', 'TopKJoin-K: Re':'SynK',
                   'EJoin-UNI: Re':'SimU', 'EJoin-K: Re':'SimK',                
                   'syntactic-UNI: Re':'BlU', 'syntactic-K: Re':'BlK',
                   'CU: Re':'CU', 'CO: Re':'CO','DB: Re':'DB', 'JDM: Re':'JDM', 
                   'SF: Re':'SF', 'EmbDI: Re': 'EmbDI', 'UNICORN: Re':'UNC'}, inplace=True)
cols = list(re.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
re = re[cols]
re
# Out:
#            SemU        SemK        SynU        SynK        SimU        SimK  \
# 333   68.750000   75.000000   43.750000   43.750000   43.750000   37.500000
# 334   54.545455   90.909091   45.454545   54.545455   45.454545   54.545455
# 335   63.636364   72.727273   54.545455   54.545455   45.454545   45.454545
# 336   72.727273   81.818182   72.727273   54.545455   72.727273   54.545455
# 337  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# ..          ...         ...         ...         ...         ...         ...
# 449  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 450   72.727273   72.727273   36.363636   54.545455   36.363636   36.363636
# 451  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 452   83.333333   83.333333   66.666667   50.000000   66.666667   50.000000
# 453   87.500000   87.500000  100.000000  100.000000   87.500000   87.500000
#
# ...

# %%
ax = sns.boxplot(re)
ax.set_title("Recall") 
ax.tick_params(axis='both', labelsize=12)
plt.ylim(-1, 101)
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_re')

# %%
re.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    78.260957   78.503801   53.521976   52.945539   53.702229   49.894154
# std     18.400938   19.129075   27.864970   28.665440   27.776396   29.339767
# min     32.000000   34.285714    0.000000    0.000000    0.000000    0.000000
# 25%     65.714286   64.000000   40.000000   33.333333   43.750000   32.000000
# 50%     81.250000   81.818182   54.545455   50.000000   53.333333   45.454545
# 75%    100.000000  100.000000   66.666667   66.666667   66.666667   63.636364
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               BlU         BlK          CO          CU          DB          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    52.840703   44.623815    2.779534   26.172364   42.865658   28.501932
# ...

# %%
pr = datasets.filter(regex='Pr').copy()
pr.rename(columns={'UNI: Pr':'SemU', 'K: Pr':'SemK', 'TopKJoin-UNI: Pr':'SynU', 'TopKJoin-K: Pr':'SynK',
                   'EJoin-UNI: Pr':'SimU', 'EJoin-K: Pr':'SimK',                
                   'syntactic-UNI: Pr':'BlU', 'syntactic-K: Pr':'BlK',
                   'CU: Pr':'CU', 'CO: Pr':'CO','DB: Pr':'DB', 'JDM: Pr':'JDM', 
                   'SF: Pr':'SF', 'EmbDI: Pr': 'EmbDI', 'UNICORN: Pr':'UNC'}, inplace=True)
cols = list(pr.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
pr = pr[cols]
pr
# Out:
#            SemU        SemK        SynU        SynK       SimU        SimK  \
# 333   78.571429   85.714286   58.333333   77.777778  58.333333  100.000000
# 334   85.714286   76.923077   41.666667   75.000000  41.666667   75.000000
# 335   77.777778   88.888889  100.000000  100.000000  83.333333  100.000000
# 336   80.000000   90.000000   66.666667   85.714286  66.666667   85.714286
# 337   25.000000   33.333333   33.333333   33.333333  33.333333   33.333333
# ..          ...         ...         ...         ...        ...         ...
# 449  100.000000  100.000000   50.000000   50.000000  50.000000   50.000000
# 450   72.727273   72.727273   80.000000   60.000000  44.444444   44.444444
# 451  100.000000  100.000000   50.000000   50.000000  50.000000   50.000000
# 452  100.000000  100.000000   50.000000   50.000000  50.000000   50.000000
# 453   77.777778   87.500000   80.000000   80.000000  87.500000   87.500000
#
# ...

# %%
ax = sns.boxplot(pr)
ax.set_title("Precision") 
ax.tick_params(axis='both', labelsize=12)
plt.xticks(rotation=45)
plt.ylim(-1, 101)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_pr')

# %%
pr.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    64.040653   69.516913   54.455345   61.014234   49.670024   57.572174
# std     26.841333   26.352787   25.754169   25.613948   23.690401   25.705631
# min      9.090909    9.090909    0.000000    0.000000    0.000000    0.000000
# 25%     48.648649   57.142857   46.666667   50.000000   40.000000   45.000000
# 50%     70.000000   76.000000   58.064516   66.666667   50.000000   58.333333
# 75%     83.333333   88.888889   69.696970   77.777778   66.666667   75.000000
# max    100.000000  100.000000  100.000000  100.000000   92.857143  100.000000
#
#               BlU         BlK          CO          CU          DB          SF  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    64.553566   62.107533    8.097862   12.976566   52.815984   25.747359
# ...

# %%
f1['max_value'] = f1.max(axis=1)
f1
# Out:
#            SemU        SemK       SynU       SynK       SimU       SimK  \
# 333   73.333333   80.000000  50.000000  56.000000  50.000000  54.545455
# 334   66.666667   83.333333  43.478261  63.157895  43.478261  63.157895
# 335   70.000000   80.000000  70.588235  70.588235  58.823529  62.500000
# 336   76.190476   85.714286  69.565217  66.666667  69.565217  66.666667
# 337   40.000000   50.000000  50.000000  50.000000  50.000000  50.000000
# ..          ...         ...        ...        ...        ...        ...
# 449  100.000000  100.000000  66.666667  66.666667  66.666667  66.666667
# 450   72.727273   72.727273  50.000000  57.142857  40.000000  40.000000
# 451  100.000000  100.000000  66.666667  66.666667  66.666667  66.666667
# 452   90.909091   90.909091  57.142857  50.000000  57.142857  50.000000
# 453   82.352941   87.500000  88.888889  88.888889  87.500000  87.500000
#
#            BlU        BlK         CO         CU          DB         SF  \
# ...

# %%
f1['SemU_DFT'] = 1- f1['SemU']/f1['max_value']
f1['SemK_DFT'] = 1- f1['SemK']/f1['max_value']
f1['SynU_DFT'] = 1- f1['SynU']/f1['max_value']
f1['SynK_DFT'] = 1- f1['SynK']/f1['max_value']
f1['SimU_DFT'] = 1- f1['SimU']/f1['max_value']
f1['SimK_DFT'] = 1- f1['SimK']/f1['max_value']
f1['BlU_DFT'] = 1- f1['BlU']/f1['max_value']
f1['BlK_DFT'] = 1- f1['BlK']/f1['max_value']
f1['CU_DFT'] = 1- f1['CU']/f1['max_value']
f1['CO_DFT'] = 1- f1['CO']/f1['max_value']
f1['DB_DFT'] = 1- f1['DB']/f1['max_value']
f1['JDM_DFT'] = 1- f1['JDM']/f1['max_value']
f1['SF_DFT'] = 1- f1['SF']/f1['max_value']
#f1['EMBDI_DFT'] = 1- f1['EmbDI']/f1['max_value']
f1['UNC_DFT'] = 1- f1['UNC']/f1['max_value']
f1
# Out:
#            SemU        SemK       SynU       SynK       SimU       SimK  \
# 333   73.333333   80.000000  50.000000  56.000000  50.000000  54.545455
# 334   66.666667   83.333333  43.478261  63.157895  43.478261  63.157895
# 335   70.000000   80.000000  70.588235  70.588235  58.823529  62.500000
# 336   76.190476   85.714286  69.565217  66.666667  69.565217  66.666667
# 337   40.000000   50.000000  50.000000  50.000000  50.000000  50.000000
# ..          ...         ...        ...        ...        ...        ...
# 449  100.000000  100.000000  66.666667  66.666667  66.666667  66.666667
# 450   72.727273   72.727273  50.000000  57.142857  40.000000  40.000000
# 451  100.000000  100.000000  66.666667  66.666667  66.666667  66.666667
# 452   90.909091   90.909091  57.142857  50.000000  57.142857  50.000000
# 453   82.352941   87.500000  88.888889  88.888889  87.500000  87.500000
#
#            BlU        BlK         CO         CU  ...  SimU_DFT  SimK_DFT  \
# ...

# %%
dft = f1.filter(regex='DFT').copy()
dft
# Out:
#      SemU_DFT  SemK_DFT  SynU_DFT  SynK_DFT  SimU_DFT  SimK_DFT   BlU_DFT  \
# 333  0.083333  0.000000  0.375000  0.300000  0.375000  0.318182  0.230769
# 334  0.200000  0.000000  0.478261  0.242105  0.478261  0.242105  0.200000
# 335  0.168750  0.050000  0.161765  0.161765  0.301471  0.257812  0.161765
# 336  0.111111  0.000000  0.188406  0.222222  0.188406  0.222222  0.416667
# 337  0.600000  0.500000  0.500000  0.500000  0.500000  0.500000  0.333333
# ..        ...       ...       ...       ...       ...       ...       ...
# 449  0.000000  0.000000  0.333333  0.333333  0.333333  0.333333  1.000000
# 450  0.163636  0.163636  0.425000  0.342857  0.540000  0.540000  0.080000
# 451  0.000000  0.000000  0.333333  0.333333  0.333333  0.333333  1.000000
# 452  0.015152  0.015152  0.380952  0.458333  0.380952  0.458333  0.097222
# 453  0.117647  0.062500  0.047619  0.047619  0.062500  0.062500  0.081633
#
#       BlK_DFT    CU_DFT    CO_DFT    DB_DFT   JDM_DFT    SF_DFT   UNC_DFT
# ...

# %%
dft.describe()
# Out:
#          SemU_DFT    SemK_DFT    SynU_DFT    SynK_DFT    SimU_DFT    SimK_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.148593    0.101963    0.366666    0.358487    0.391600    0.397417
# std      0.170929    0.164083    0.276773    0.241598    0.266991    0.247229
# min      0.000000    0.000000    0.000000    0.000000    0.005217    0.000000
# 25%      0.002358    0.000000    0.200000    0.222222    0.244792    0.256410
# 50%      0.097222    0.015152    0.333333    0.323529    0.333333    0.333333
# 75%      0.200000    0.142857    0.425000    0.449573    0.478261    0.500000
# max      0.600000    0.600000    1.000000    1.000000    1.000000    1.000000
#
#           BlU_DFT     BlK_DFT      CU_DFT      CO_DFT      DB_DFT     JDM_DFT  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     0.301040    0.391988    0.784995    0.953168    0.474706    0.200351
# ...

# %%
dft.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
rt = datasets.filter(regex='runtime').copy()
rt.rename(columns={'UNI: runtime':'SemU', 'K: runtime':'SemK', 'TopKJoin-UNI: runtime':'SynU', 'TopKJoin-K: runtime':'SynK',
                   'EJoin-UNI: runtime':'SimU', 'EJoin-K: runtime':'SimK',                
                   'syntactic-UNI: runtime':'BlU', 'syntactic-K: runtime':'BlK',
                   'CU: runtime':'CU', 'CO: runtime':'CO','DB: runtime':'DB', 'JDM: runtime':'JDM', 
                   'SF: runtime':'SF', 'EmbDI: runtime': 'EmbDI', 'UNICORN: runtime':'UNC'}, inplace=True)
cols = list(rt.columns)
i, j = cols.index('SimU'), cols.index('SynK')
cols[i], cols[j] = cols[j], cols[i]
rt = rt[cols]
rt
# Out:
#           SemU       SemK      SynU      SynK      SimU      SimK         BlU  \
# 333  88.219780  88.286029  0.085431  0.152879  0.084595  0.165090    0.097629
# 334   9.211126  27.488940  0.049428  0.110429  0.046923  0.112068    0.135831
# 335  11.622646  11.677392  0.046108  0.101177  0.044882  0.109546    0.500212
# 336  29.227151  29.368605  0.074581  0.129810  0.072495  0.139446    0.177308
# 337   5.669960  20.100148  0.098636  0.133390  0.026897  0.066772    0.136385
# ..         ...        ...       ...       ...       ...       ...         ...
# 449   3.456857   3.490351  0.064033  0.098409  0.062173  0.100446    2.164212
# 450  33.656137  33.546855  0.129808  0.195535  0.178982  0.312844   32.580441
# 451   3.856011   3.889479  0.065114  0.100329  0.062438  0.100907    2.163194
# 452   9.134220   9.180413  0.089306  0.136678  0.088042  0.144596   29.382003
# 453  10.684985   7.523525  0.132709  0.183273  0.131905  0.202947  136.092910
#
# ...

# %%
ax = sns.boxplot(rt)
ax.set_title("Run-time") 
ax.tick_params(axis='both', labelsize=12)
plt.yscale('log')
plt.xticks(rotation=45)
plt.savefig(main_dir + 'composite_'+ dataset_type + '_rt')

# %%
rt.describe()
# Out:
#              SemU        SemK        SynU        SynK        SimU        SimK  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    23.219674   27.325360    0.096842    0.163952    0.095443    0.192791
# std     21.688225   20.756746    0.046855    0.076830    0.048529    0.106737
# min      3.414224    3.445723    0.026607    0.061553    0.025663    0.065365
# 25%      5.560078    7.042514    0.061421    0.104163    0.062438    0.112927
# 50%     10.730891   27.683722    0.088173    0.143740    0.082981    0.156398
# 75%     36.934882   43.560601    0.128702    0.205821    0.128275    0.255089
# max     88.219780   88.286029    0.201906    0.357174    0.207339    0.447276
#
#               BlU         BlK           CO          CU          DB  \
# count  121.000000  121.000000   121.000000  121.000000  121.000000
# mean     6.467526   10.019984   349.159625   18.712333   22.101380
# ...
