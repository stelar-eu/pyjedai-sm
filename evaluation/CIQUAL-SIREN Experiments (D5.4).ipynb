# %% [markdown]
# <div align="center">
# <img align="center" src="https://stelar-project.eu/wp-content/uploads/2022/08/cropped-stelar-sq.png?raw=true" alt="pyJedAI" width="250"/>
#
# <strong>Deduplication Use Case</strong>
# </div>
# <div align="center">
# <img align="center" src="https://github.com/AI-team-UoA/.github/blob/main/AI_LOGO-1.png?raw=true" alt="pyJedAI" width="160"/>
# <img align="center" src="https://agroknow.com/wp-content/uploads/2020/04/logo_agroknow_sm.png?raw=true" alt="pyJedAI" width="160"/>
# <img align="center" src="https://github.com/Nikoletos-K/pyJedAI/blob/main/docs/img/pyjedai.logo.drawio.png?raw=true" alt="pyJedAI" width="250"/>
# </div>
#
# ---

# %% [markdown]
# # Initialize data and pyJedAI
# Execute cell to initialize application and read the data.

# %%
# %pip install pyjedai
# Out:
# Requirement already satisfied: pyjedai in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (0.3.6)
# Requirement already satisfied: matplotlib in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (3.9.4)
# Requirement already satisfied: networkx in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (3.2.1)
# Requirement already satisfied: nltk in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (3.9.2)
# Requirement already satisfied: numpy<3.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (2.0.2)
# Requirement already satisfied: pandas in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (2.2.3)
# Requirement already satisfied: scipy in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (1.13.1)
# Requirement already satisfied: seaborn in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (0.13.2)
# Requirement already satisfied: tqdm in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (4.67.1)
# Requirement already satisfied: transformers in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (4.57.1)
# Requirement already satisfied: sentence-transformers in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (5.1.2)
# Requirement already satisfied: faiss-cpu in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (1.12.0)
# Requirement already satisfied: valentine in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (0.3.0)
# Requirement already satisfied: ordered-set in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (4.1.0)
# Requirement already satisfied: shapely in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (2.0.7)
# Requirement already satisfied: ollama in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (0.6.0)
# Requirement already satisfied: py-stringcompare in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (0.2.2)
# Requirement already satisfied: ray in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pyjedai) (2.51.1)
# Requirement already satisfied: packaging in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from faiss-cpu->pyjedai) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from matplotlib->pyjedai) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pyjedai) (3.23.0)
# Requirement already satisfied: six>=1.5 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->pyjedai) (1.17.0)
# Requirement already satisfied: click in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from nltk->pyjedai) (8.1.8)
# Requirement already satisfied: joblib in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from nltk->pyjedai) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from nltk->pyjedai) (2025.11.3)
# Requirement already satisfied: httpx>=0.27 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ollama->pyjedai) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ollama->pyjedai) (2.12.3)
# Requirement already satisfied: anyio in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (4.11.0)
# Requirement already satisfied: certifi in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (1.0.9)
# Requirement already satisfied: idna in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27->ollama->pyjedai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (0.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from anyio->httpx>=0.27->ollama->pyjedai) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from anyio->httpx>=0.27->ollama->pyjedai) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pandas->pyjedai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from pandas->pyjedai) (2025.2)
# Requirement already satisfied: pybind11<4,>=2.4 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from py-stringcompare->pyjedai) (3.0.1)
# Requirement already satisfied: filelock in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ray->pyjedai) (3.19.1)
# Requirement already satisfied: jsonschema in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ray->pyjedai) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ray->pyjedai) (1.1.2)
# Requirement already satisfied: protobuf>=3.20.3 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ray->pyjedai) (6.33.0)
# Requirement already satisfied: pyyaml in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ray->pyjedai) (6.0.3)
# Requirement already satisfied: requests in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from ray->pyjedai) (2.32.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from jsonschema->ray->pyjedai) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from jsonschema->ray->pyjedai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from jsonschema->ray->pyjedai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from jsonschema->ray->pyjedai) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from requests->ray->pyjedai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from requests->ray->pyjedai) (2.5.0)
# Requirement already satisfied: torch>=1.11.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from sentence-transformers->pyjedai) (2.7.1+cu118)
# Requirement already satisfied: scikit-learn in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from sentence-transformers->pyjedai) (1.6.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from sentence-transformers->pyjedai) (0.36.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from transformers->pyjedai) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from transformers->pyjedai) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->pyjedai) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->pyjedai) (1.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (1.14.0)
# Requirement already satisfied: jinja2 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from triton==3.3.1->torch>=1.11.0->sentence-transformers->pyjedai) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers->pyjedai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers->pyjedai) (3.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from scikit-learn->sentence-transformers->pyjedai) (3.6.0)
# Requirement already satisfied: anytree<3.0,>=2.9 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from valentine->pyjedai) (2.13.0)
# Requirement already satisfied: chardet<6.0.0,>=5.2.0 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from valentine->pyjedai) (5.2.0)
# Requirement already satisfied: jellyfish<1.2,>=0.9 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from valentine->pyjedai) (1.1.3)
# Requirement already satisfied: PuLP<3.0,>=2.5 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from valentine->pyjedai) (2.9.0)
# Requirement already satisfied: POT<1.0,>=0.9.5 in /home/teris45/miniconda3/envs/pyjedai/lib/python3.9/site-packages (from valentine->pyjedai) (0.9.6.post1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load CIQUAL-SIREN Data

# %%
import pandas as pd
from pyjedai.schema.schema_model import Schema

d1 = pd.read_csv('ciqual-siren/source.csv', na_filter=True).astype(str)
d2 = pd.read_csv('ciqual-siren/target.csv', na_filter=True).astype(str)
gt = pd.read_csv('ciqual-siren/mappings_of_labels.csv', na_filter=True).astype(str)


# Initializing Ciqual Siren Data
source_col = d1['label'].to_list()
source_data = [i for i in range(len(source_col))]
source_df = pd.DataFrame(columns = source_col, data=[source_data])
 

target_col = d2['label'].to_list()
target_data = [i for i in range(len(target_col))]
target_df = pd.DataFrame(columns = target_col, data=[target_data])

schema = Schema(dataset_1=source_df, dataset_2= target_df, ground_truth=gt, matching_type="SCHEMA")

# %% [markdown]
# # pyJedAI Semantic Schema Matching

# %% [markdown]
# Best workflow for CIQUAL-SIREN was `{'language_model': 'sdistilroberta', 'similarity': 0.80, 'top_k': 1, 'reversed': False}`

# %%
from pyjedai.vector_based_blocking import EmbeddingsNNBlockBuilding
from pyjedai.clustering import UniqueMappingClustering

similarity = 0.80

emb = EmbeddingsNNBlockBuilding(vectorizer='sdistilroberta')
_, graph = emb.build_blocks(schema,
    top_k=1,
    with_entity_matching=True,
    load_embeddings_if_exist=True)

# Clustering
clustering = UniqueMappingClustering()
clusters = clustering.process(graph, schema, similarity)
ev = clustering.evaluate(clusters)
# Out:
# Embeddings-NN Block Building [sdistilroberta, faiss, cuda]:   0%|          | 0/22693 [00:00<?, ?it/s]
# ***************************************************************************************************************************
#                                          Method:  Unique Mapping Clustering
# ***************************************************************************************************************************
# Method name: Unique Mapping Clustering
# Parameters:
# 	Similarity Threshold: 0.8
# Runtime: 0.0407 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.52%
# 	Recall:         0.56%
# 	F1-score:       0.54%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
df = clustering.export_to_df(clusters)
print(f'Number of Matches found in CIQUAL-SIREN: {len(df)}')
# Out:
# Number of Matches found in CIQUAL-SIREN: 193

# %%
merge = df.merge(right=schema.dataset_1, left_on='id1', right_on='id', how='inner')
merge = merge.drop(columns=['id1', 'id'])
merge.columns = ['id2', 'ciqual']

merge = merge.merge(right=schema.dataset_2, left_on='id2', right_on='id', how='inner')

merge = merge.drop(columns=['id2', 'id'])
merge.columns = ['CIQUAL', 'SIREN']

merge
# Out:
#                         CIQUAL                          SIREN
# 0                       Peanut                         PEANUT
# 1                      Mustard                        MUSTARD
# 2                       Nutmeg                         NUTMEG
# 3                        Prune                          PRUNE
# 4                   Brazil nut                     BRAZIL NUT
# ..                         ...                            ...
# 188               Onion, dried   onion (fried, dehydrated)@en
# 189         Bamboo shoots, raw          bamboo shoot (raw)@en
# 190                Cumin, seed                          CUMIN
# 191  Potato, sautéed/pan-fried  potato (pre-fried, sliced)@en
# 192               Rapeseed oil                rapeseed oil@en
#
# [193 rows x 2 columns]

# %% [markdown]
# ## pyJedAI Syntactic Schema Matching with Kiraly Clustering

# %% [markdown]
# ### Standard Blocking

# %%
from pyjedai.block_building import StandardBlocking

sb = StandardBlocking(disable_ray=True)
blocks = sb.build_blocks(schema)
# Out:
# Standard Blocking:   0%|          | 0/22693 [00:00<?, ?it/s]
# [2025-11-04 14:25:03,991 E 17777 24225] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14

# %% [markdown]
# ### Block Filtering

# %%
from pyjedai.block_cleaning import BlockFiltering

bf = BlockFiltering(ratio=0.5)
filtered_blocks = bf.process(blocks, schema)
# Out:
# Block Filtering:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### Comparison Cleaning

# %%
from pyjedai.comparison_cleaning import CardinalityNodePruning


ws = 'JS'	

cc = CardinalityNodePruning(weighting_scheme=ws)
meta_blocks = cc.process(filtered_blocks, schema)
# Out:
# Cardinality Node Pruning:   0%|          | 0/22693 [00:00<?, ?it/s]

# %% [markdown]
# ### Entity Matching

# %%
from pyjedai.matching import EntityMatching

em = EntityMatching(tokenizer='white_space_tokenizer', metric='generalized_jaccard', similarity_threshold=0.85)
graph = em.predict(meta_blocks, schema)
# Out:
# Entity Matching (generalized_jaccard, white_space_tokenizer):   0%|          | 0/17724 [00:00<?, ?it/s]

# %% [markdown]
# ### Clustering

# %%
from pyjedai.clustering import KiralyMSMApproximateClustering

k_cl = KiralyMSMApproximateClustering()

clusters = k_cl.process(graph, schema)
_ = k_cl.evaluate(clusters)
# Out:
# ***************************************************************************************************************************
#                                          Method:  Kiraly MSM Approximate Clustering
# ***************************************************************************************************************************
# Method name: Kiraly MSM Approximate Clustering
# Parameters:
# 	Similarity Threshold: 0.1
# Runtime: 0.0603 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.13%
# 	Recall:         0.56%
# 	F1-score:       0.22%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
df = clustering.export_to_df(clusters)
print(f'Number of Matches found in CIQUAL-SIREN: {len(df)}')
merge = df.merge(right=schema.dataset_1, left_on='id1', right_on='id', how='inner')
merge = merge.drop(columns=['id1', 'id'])
merge.columns = ['id2', 'ciqual']

merge = merge.merge(right=schema.dataset_2, left_on='id2', right_on='id', how='inner')

merge = merge.drop(columns=['id2', 'id'])
merge.columns = ['CIQUAL', 'SIREN']

merge
# Out:
# Number of Matches found in CIQUAL-SIREN: 741
#                                                 CIQUAL                                              SIREN
# 0    Olive, green, stuffed (anchovy, sweet peppers,...  10006190 - SQUARE SWEET PEPPERS (BLUNT) (GS1 GPC)
# 1                                           Squid, raw                                       squid raw@en
# 2                                           Snail, raw                                     snail (raw)@en
# 3                     Clear fruit brandy or eau-de-vie                      33870 - BRANDY (EFSA FOODEX2)
# 4                                         Lobster, raw                                lobster (frozen)@en
# ..                                                 ...                                                ...
# 736            Dark chocolate bar, filled with praline               33400 - DARK ALE BEER (EFSA FOODEX2)
# 737             Toblerone milk cholcolate bar w nougat              43290 - NOUGAT FLAVOUR (EFSA FOODEX2)
# 738                            Pollen, partially dried                              FAT PARTIALLY REMOVED
# 739                                 Jam, reduced sugar                                jam food product@en
# 740               Cereal bar with almonds or hazelnuts                   11420 - HAZELNUTS (EFSA FOODEX2)
#
# [741 rows x 2 columns]

# %% [markdown]
# ## pyJedAI Join Schema Matching with Kiraly Clustering

# %% [markdown]
# TopK-Join Matching with arguments : `{'metric': 'cosine', 'tokenization': 'qgrams', 'qgrams': 2, 'K': 1}`

# %%
from pyjedai.joins import TopKJoin


join = TopKJoin(K=1, metric='cosine', tokenization='qgrams', qgrams=2)
graph = join.fit(schema)
clustering = UniqueMappingClustering()
clusters = clustering.process(graph, schema)
ev = clustering.evaluate(clusters)
# Out:
# Top-K Join (cosine):   0%|          | 0/19886 [00:00<?, ?it/s]
# ***************************************************************************************************************************
#                                          Method:  Unique Mapping Clustering
# ***************************************************************************************************************************
# Method name: Unique Mapping Clustering
# Parameters:
# 	Similarity Threshold: 0.1
# Runtime: 0.2841 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.00%
# 	Recall:         0.00%
# 	F1-score:       0.00%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
df = clustering.export_to_df(clusters)
print(f'Number of Matches found in CIQUAL-SIREN: {len(df)}')
merge = df.merge(right=schema.dataset_1, left_on='id1', right_on='id', how='inner')
merge = merge.drop(columns=['id1', 'id'])
merge.columns = ['id2', 'ciqual']

merge = merge.merge(right=schema.dataset_2, left_on='id2', right_on='id', how='inner')

merge = merge.drop(columns=['id2', 'id'])
merge.columns = ['CIQUAL', 'SIREN']

merge
# Out:
# Number of Matches found in CIQUAL-SIREN: 2376
#                                                  CIQUAL                                SIREN
# 0                                               Mustard                              MUSTARD
# 1                                               Saffron                              SAFFRON
# 2                                                Nutmeg                               NUTMEG
# 3                                                 Prune                                PRUNE
# 4                                                Peanut                               PEANUT
# ...                                                 ...                                  ...
# 2371         Dried pasta, gluten-free, cooked, unsalted                            glycogens
# 2372                              Rillettes, pure goose  10006746 - DOODLES/ PUFFS (GS1 GPC)
# 2373  Cooked ham, superior quality, rind less and fa...     16580 - LIMEQUATS (EFSA FOODEX2)
# 2374                       Lamb, meat, cooked (average)          10006414 - MEDLAR (GS1 GPC)
# 2375                Foie gras, duck's liver, 30% pieces           10005884 - LIMES (GS1 GPC)
#
# [2376 rows x 2 columns]
